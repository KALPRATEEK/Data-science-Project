# %% [markdown]
# # Data Sience Project: LSTM to predict the movement of stocks

# %% [markdown]
# ## GPU Test

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU available via tf.config:", tf.config.list_physical_devices('GPU'))

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 2025-06-23 08:37:36.042013: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-23 08:37:36.056859: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-23 08:37:36.074910: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-23 08:37:36.080389: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-23 08:37:36.093260: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 08:37:37.008160: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TensorFlow version: 2.17.0
# Built with CUDA: True
# GPU available via tf.config: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16150241404785552781
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 32646561792
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 422206334951780125
# physical_device_desc: "device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:5e:00.0, compute capability: 7.0"
# xla_global_id: 416903419
# ]
# 2025-06-23 08:37:37.794858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:5e:00.0, compute capability: 7.0

# %% [markdown]
# ### ML Script

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from imblearn.over_sampling import BorderlineSMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization

from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import datetime as dt

import os
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
import tensorflow as tf
tf.keras.backend.clear_session()
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))


# === Parameters ===
time_steps = 40
forward_days = 5
classes = 5

df = pd.read_csv('PLTR.csv', parse_dates=['Date'])
df = df.sort_values('Date').reset_index(drop=True)

# Calculate EMA (Exponential Moving Averages)
df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()

# Calculate MACD and Signal line
df['MACD'] = df['EMA12'] - df['EMA26']
df['MACD_signal'] = df['MACD'].ewm(span=9, adjust=False).mean()

# Calculate MACD Histogram
df['MACD_his'] = df['MACD'] - df['MACD_signal']

# Remove any rows with NaN after EMA/MACD calculations
df.dropna(inplace=True)
df = df.reset_index(drop=True)

# Then continue with your feature scaling and so on...


# === Feature selection ===
features = ['Open', 'High', 'Low', 'Close', 'Volume', 
            'MA10', 'MA20', 'MA50', 'MACD_ml', 'MACD_his', 
            'RSI14', 'OBV', 'ATR', 'StochasticMomentum']

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[features])

# === Create supervised samples ===
X, y = [], []

for i in range(len(scaled_data) - time_steps - forward_days):
    X.append(scaled_data[i:i+time_steps])
    
    current_price = df['Close'].iloc[i+time_steps-1]
    future_price = df['Close'].iloc[i+time_steps+forward_days-1]
    pct_change = (future_price - current_price) / current_price * 100
    
    if pct_change <= -2:
        label = 0  # Big drop
    elif -2 < pct_change <= -0.5:
        label = 1  # Small drop
    elif -0.5 < pct_change < 0.5:
        label = 2  # Neutral
    elif 0.5 <= pct_change < 2:
        label = 3  # Small rise
    else:
        label = 4  # Big rise
        
    y.append(label)

X, y = np.array(X), np.array(y)

# === Optional: Apply BorderlineSMOTE ===
X_reshaped = X.reshape(X.shape[0], -1)
X_resampled, y_resampled = BorderlineSMOTE(kind='borderline-2').fit_resample(X_reshaped, y)
X_resampled = X_resampled.reshape(-1, time_steps, len(features))

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1, random_state=42)

# === Model definition ===
def Create_LSTM_Model(units=128, drop_out=0.5, lr=5e-4):
    model = Sequential()
    model.add(LSTM(units=units, input_shape=(time_steps, len(features)), return_sequences=True))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(LSTM(units=units))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=units, activation='tanh'))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=5, activation='softmax'))
    
    model.compile(optimizer=Adam(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# === Training ===
model = Create_LSTM_Model()
history = model.fit(X_train, y_train, epochs=1000, batch_size=1022, validation_data=(X_test, y_test))

# === Evaluation ===
model.evaluate(X_test, y_test)
y_pred = np.argmax(model.predict(X_test), axis=1)
conf_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_mat)


from collections import Counter

counts_origin = Counter(y_test)
unique_labels = np.unique(y_test)

print("Per-class accuracy:")
for i in unique_labels:
    if i < conf_mat.shape[0] and i < conf_mat.shape[1]:
        correct = conf_mat[i, i]
        total = sum(conf_mat[i, :])  # total true samples of class i
        acc = 100 * correct / total if total > 0 else 0
        print(f"Label {i} accuracy: {acc:.1f}%")
    else:
        print(f"Label {i} not present in confusion matrix")

# === Evaluation ===
model.evaluate(X_test, y_test)
y_pred = np.argmax(model.predict(X_test), axis=1)
conf_mat = confusion_matrix(y_test, y_pred)


# === Manually inspect one test sample ===

# REBUILD the index map used when creating X and y
X_indices = []
for i in range(len(scaled_data) - time_steps - forward_days):
    X_indices.append(i)
X_indices = np.array(X_indices)

# Re-split the indices just like the features
_, X_test_indices = train_test_split(X_indices, test_size=0.1, random_state=42)

# Choose a test sample index to inspect (between 0 and len(X_test)-1)
test_sample_idx = 5  # Change this number as desired

# Get original index in the full df for this test sample
original_df_index = X_test_indices[test_sample_idx]

# Display relevant info
print("\n=== Manual Prediction Inspection ===")
print(f"Sample index in df: {original_df_index}")
print("Current date:", df.iloc[original_df_index + time_steps - 1]['Date'])
print("Future date:", df.iloc[original_df_index + time_steps + forward_days - 1]['Date'])
print("Current price:", df.iloc[original_df_index + time_steps - 1]['Close'])
print("Future price:", df.iloc[original_df_index + time_steps + forward_days - 1]['Close'])
print(f"Actual % change: {((df.iloc[original_df_index + time_steps + forward_days - 1]['Close'] - df.iloc[original_df_index + time_steps - 1]['Close']) / df.iloc[original_df_index + time_steps - 1]['Close']) * 100:.2f}%")
print(f"True label: {y_test[test_sample_idx]} (actual movement class)")
print(f"Predicted label: {y_pred[test_sample_idx]}")
# Out:
# Num GPUs Available: 1
# KeyboardInterrupt

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import BorderlineSMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import tensorflow as tf

print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))

# === Parameters ===
time_steps = 40
forward_days = 6
classes = 5
max_samples = 30  # Maximum number of random samples to include in Excel

# === Load data ===
df = pd.read_csv('GOOGL.csv', parse_dates=['Date'])
df = df.sort_values('Date').reset_index(drop=True)

# === Calculate indicators ===
df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
df['MACD'] = df['EMA12'] - df['EMA26']
df['MACD_signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
df['MACD_his'] = df['MACD'] - df['MACD_signal']

df.dropna(inplace=True)
df = df.reset_index(drop=True)

# === Feature selection ===
features = ['Open', 'High', 'Low', 'Close', 'Volume', 
            'MA10', 'MA20', 'MA50', 'MACD_ml', 'MACD_his', 
            'RSI14', 'OBV', 'ATR', 'StochasticMomentum']

# Make sure these columns exist or calculate them beforehand.
# For now, let's check and create missing columns with zeros to avoid errors:
for feat in features:
    if feat not in df.columns:
        df[feat] = 0.0

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[features])

# === Create supervised samples ===
X, y = [], []
for i in range(len(scaled_data) - time_steps - forward_days):
    X.append(scaled_data[i:i+time_steps])
    
    current_price = df['Close'].iloc[i+time_steps-1]
    future_price = df['Close'].iloc[i+time_steps+forward_days-1]
    pct_change = (future_price - current_price) / current_price * 100
    
    if pct_change <= -2:
        label = 0  # Big drop
    elif -2 < pct_change <= -0.5:
        label = 1  # Small drop
    elif -0.5 < pct_change < 0.5:
        label = 2  # Neutral
    elif 0.5 <= pct_change < 2:
        label = 3  # Small rise
    else:
        label = 4  # Big rise
        
    y.append(label)

X, y = np.array(X), np.array(y)

# === Apply BorderlineSMOTE ONLY on X and y ===
X_flat = X.reshape(X.shape[0], -1)
X_resampled, y_resampled = BorderlineSMOTE(kind='borderline-2').fit_resample(X_flat, y)
X_resampled = X_resampled.reshape(-1, time_steps, len(features))

# === Train-test split ===
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.25, random_state=42)

# === Define model ===
def Create_LSTM_Model(units=1000, drop_out=0.5, lr=5e-4):
    model = Sequential()
    model.add(LSTM(units=units, input_shape=(time_steps, len(features)), return_sequences=True))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(LSTM(units=units))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=units, activation='tanh'))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=5, activation='softmax'))
    
    model.compile(optimizer=Adam(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# === Train model ===
model = Create_LSTM_Model()

from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(patience=150, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=1000, batch_size=512, validation_data=(X_test, y_test), callbacks=[early_stop])

# === Evaluate model ===
model.evaluate(X_test, y_test)
y_pred = np.argmax(model.predict(X_test), axis=1)
conf_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_mat)

from collections import Counter
counts_origin = Counter(y_test)
unique_labels = np.unique(y_test)

print("Per-class accuracy:")
for i in unique_labels:
    if i < conf_mat.shape[0] and i < conf_mat.shape[1]:
        correct = conf_mat[i, i]
        total = sum(conf_mat[i, :])
        acc = 100 * correct / total if total > 0 else 0
        print(f"Label {i} accuracy: {acc:.1f}%")
    else:
        print(f"Label {i} not present in confusion matrix")

# === Map test samples back to original indices where possible ===
X_flat_original = X.reshape(X.shape[0], -1)

idx_test = []
for test_sample in X_test.reshape(X_test.shape[0], -1):
    matches = np.where((X_flat_original == test_sample).all(axis=1))[0]
    if len(matches) > 0:
        idx_test.append(matches[0])
    else:
        idx_test.append(-1)  # synthetic sample

idx_test = np.array(idx_test)

# === Randomly select indices for comparison ===
np.random.seed()  # Ensure randomness each run
non_synthetic_indices = np.where(idx_test != -1)[0]
random_indices = np.random.choice(non_synthetic_indices, size=min(max_samples, len(non_synthetic_indices)), replace=False)

# === Create a DataFrame with predictions and actual values for random dates ===
results = []
for i in random_indices:
    original_idx = idx_test[i]
    current_price = df.iloc[original_idx + time_steps - 1]['Close']
    future_price = df.iloc[original_idx + time_steps + forward_days - 1]['Close']
    actual_pct_change = (future_price - current_price) / current_price * 100
    predicted_label = y_pred[i]
    true_label = y_test[i]

    results.append({
        'Current_Date': df.iloc[original_idx + time_steps - 1]['Date'],
        'Future_Date': df.iloc[original_idx + time_steps + forward_days - 1]['Date'],
        'Current_Price': current_price,
        'Future_Price': future_price,
        'Predicted_Label': predicted_label,
        'True_Label': true_label,
        'Actual_Pct_Change': actual_pct_change
    })

results_df = pd.DataFrame(results)

# Save to Excel
results_df.to_excel('prediction_results.xlsx', index=False)

print("\nSaved prediction results to 'prediction_results.xlsx'")

# === Manual inspection example for one random test sample (non-synthetic) ===
if len(random_indices) > 0:
    sample_i = random_indices[0]
    original_df_index = idx_test[sample_i]

    print("\n=== Manual Prediction Inspection ===")
    print(f"Sample index in df: {original_df_index}")
    print("Current date:", df.iloc[original_df_index + time_steps - 1]['Date'])
    print("Future date:", df.iloc[original_df_index + time_steps + forward_days - 1]['Date'])
    print("Current price:", df.iloc[original_df_index + time_steps - 1]['Close'])
    print("Future price:", df.iloc[original_df_index + time_steps + forward_days - 1]['Close'])
    print(f"Actual % change: {((df.iloc[original_df_index + time_steps + forward_days - 1]['Close'] - df.iloc[original_df_index + time_steps - 1]['Close']) / df.iloc[original_df_index + time_steps - 1]['Close']) * 100:.2f}%")
    print(f"True label: {y_test[sample_i]} (actual movement class)")
    print(f"Predicted label: {y_pred[sample_i]}")
else:
    print("No non-synthetic test samples found for manual inspection.")
# Out:
# Num GPUs Available: 1
# /opt/conda/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1781 - loss: 2.2484 - val_accuracy: 0.4286 - val_loss: 1.4217
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4658 - loss: 2.0283 - val_accuracy: 0.3469 - val_loss: 1.4282
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5479 - loss: 1.4757 - val_accuracy: 0.4286 - val_loss: 1.4480
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5479 - loss: 1.2538 - val_accuracy: 0.4694 - val_loss: 1.3631
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5822 - loss: 1.0996 - val_accuracy: 0.5918 - val_loss: 1.2869
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5822 - loss: 1.2175 - val_accuracy: 0.6122 - val_loss: 1.2542
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5959 - loss: 1.1089 - val_accuracy: 0.5510 - val_loss: 1.2703
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6301 - loss: 1.0939 - val_accuracy: 0.4286 - val_loss: 1.2856
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5137 - loss: 1.2054 - val_accuracy: 0.5306 - val_loss: 1.2380
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6164 - loss: 1.0793 - val_accuracy: 0.5306 - val_loss: 1.1941
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6575 - loss: 0.9015 - val_accuracy: 0.5918 - val_loss: 1.1608
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5959 - loss: 1.0188 - val_accuracy: 0.6122 - val_loss: 1.1404
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6233 - loss: 0.9427 - val_accuracy: 0.5714 - val_loss: 1.1331
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6370 - loss: 0.8676 - val_accuracy: 0.4898 - val_loss: 1.1409
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7055 - loss: 0.8995 - val_accuracy: 0.4694 - val_loss: 1.1584
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6849 - loss: 0.9705 - val_accuracy: 0.4898 - val_loss: 1.1412
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6575 - loss: 0.8445 - val_accuracy: 0.4898 - val_loss: 1.0765
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7534 - loss: 0.7013 - val_accuracy: 0.4694 - val_loss: 1.0293
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7192 - loss: 0.7458 - val_accuracy: 0.4898 - val_loss: 1.0192
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6438 - loss: 0.8825 - val_accuracy: 0.4694 - val_loss: 1.0385
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6918 - loss: 0.7443 - val_accuracy: 0.4898 - val_loss: 1.0620
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7260 - loss: 0.7457 - val_accuracy: 0.5102 - val_loss: 1.0793
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7055 - loss: 0.7907 - val_accuracy: 0.5510 - val_loss: 1.0667
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7055 - loss: 0.7104 - val_accuracy: 0.5714 - val_loss: 1.0469
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7192 - loss: 0.6939 - val_accuracy: 0.5510 - val_loss: 1.0513
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6918 - loss: 0.7071 - val_accuracy: 0.5306 - val_loss: 1.0559
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6849 - loss: 0.8531 - val_accuracy: 0.5102 - val_loss: 1.0260
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6986 - loss: 0.7954 - val_accuracy: 0.5510 - val_loss: 0.9955
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7808 - loss: 0.6485 - val_accuracy: 0.5714 - val_loss: 0.9780
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7603 - loss: 0.6443 - val_accuracy: 0.5510 - val_loss: 0.9988
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6918 - loss: 0.8196 - val_accuracy: 0.5714 - val_loss: 1.0343
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8082 - loss: 0.5535 - val_accuracy: 0.5510 - val_loss: 1.0556
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8082 - loss: 0.5632 - val_accuracy: 0.5510 - val_loss: 1.0818
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7466 - loss: 0.6346 - val_accuracy: 0.5510 - val_loss: 1.1076
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7740 - loss: 0.5548 - val_accuracy: 0.5510 - val_loss: 1.0977
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7671 - loss: 0.5702 - val_accuracy: 0.5306 - val_loss: 1.0646
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8356 - loss: 0.4697 - val_accuracy: 0.5306 - val_loss: 1.0396
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7808 - loss: 0.6222 - val_accuracy: 0.5918 - val_loss: 1.0357
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7534 - loss: 0.6060 - val_accuracy: 0.6122 - val_loss: 1.0452
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7603 - loss: 0.5915 - val_accuracy: 0.5918 - val_loss: 1.0867
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7740 - loss: 0.5750 - val_accuracy: 0.6122 - val_loss: 1.1294
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7603 - loss: 0.6194 - val_accuracy: 0.5918 - val_loss: 1.1430
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7671 - loss: 0.6187 - val_accuracy: 0.6122 - val_loss: 1.1695
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7466 - loss: 0.6840 - val_accuracy: 0.6122 - val_loss: 1.1288
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8219 - loss: 0.4648 - val_accuracy: 0.6122 - val_loss: 1.1084
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7671 - loss: 0.5334 - val_accuracy: 0.5510 - val_loss: 1.0989
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7945 - loss: 0.5254 - val_accuracy: 0.5306 - val_loss: 1.1094
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8151 - loss: 0.4946 - val_accuracy: 0.5510 - val_loss: 1.1437
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7808 - loss: 0.4827 - val_accuracy: 0.5510 - val_loss: 1.1540
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7808 - loss: 0.4723 - val_accuracy: 0.5714 - val_loss: 1.1383
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7534 - loss: 0.5587 - val_accuracy: 0.6327 - val_loss: 1.0907
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8014 - loss: 0.4927 - val_accuracy: 0.6327 - val_loss: 1.0529
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7877 - loss: 0.4977 - val_accuracy: 0.6531 - val_loss: 1.0486
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7945 - loss: 0.5001 - val_accuracy: 0.6531 - val_loss: 1.0518
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8151 - loss: 0.5235 - val_accuracy: 0.6327 - val_loss: 1.0605
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7945 - loss: 0.5161 - val_accuracy: 0.5510 - val_loss: 1.0825
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7945 - loss: 0.5671 - val_accuracy: 0.5918 - val_loss: 1.0373
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7466 - loss: 0.6122 - val_accuracy: 0.6122 - val_loss: 0.9811
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8014 - loss: 0.5106 - val_accuracy: 0.6531 - val_loss: 0.9938
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8082 - loss: 0.4750 - val_accuracy: 0.6327 - val_loss: 1.0108
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8493 - loss: 0.4153 - val_accuracy: 0.6735 - val_loss: 1.0203
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8219 - loss: 0.5295 - val_accuracy: 0.7347 - val_loss: 1.0205
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7808 - loss: 0.5879 - val_accuracy: 0.7347 - val_loss: 1.0352
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7740 - loss: 0.5208 - val_accuracy: 0.6531 - val_loss: 1.0827
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7945 - loss: 0.5578 - val_accuracy: 0.6122 - val_loss: 1.1061
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8151 - loss: 0.4959 - val_accuracy: 0.6327 - val_loss: 1.1036
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7808 - loss: 0.4750 - val_accuracy: 0.6122 - val_loss: 1.1395
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7877 - loss: 0.4275 - val_accuracy: 0.6122 - val_loss: 1.1941
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8767 - loss: 0.3691 - val_accuracy: 0.6122 - val_loss: 1.2170
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8219 - loss: 0.4284 - val_accuracy: 0.5918 - val_loss: 1.1471
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8082 - loss: 0.4285 - val_accuracy: 0.6735 - val_loss: 1.0607
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8151 - loss: 0.4582 - val_accuracy: 0.6939 - val_loss: 1.0142
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7808 - loss: 0.4944 - val_accuracy: 0.7143 - val_loss: 1.0255
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8014 - loss: 0.4349 - val_accuracy: 0.6531 - val_loss: 1.0677
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8699 - loss: 0.3458 - val_accuracy: 0.6122 - val_loss: 1.1041
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8288 - loss: 0.4928 - val_accuracy: 0.6122 - val_loss: 1.0947
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8219 - loss: 0.4237 - val_accuracy: 0.5918 - val_loss: 1.0547
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8082 - loss: 0.4478 - val_accuracy: 0.5714 - val_loss: 0.9938
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8493 - loss: 0.3565 - val_accuracy: 0.6122 - val_loss: 1.0262
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8151 - loss: 0.4908 - val_accuracy: 0.6327 - val_loss: 1.0249
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8288 - loss: 0.4514 - val_accuracy: 0.6122 - val_loss: 1.0312
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8356 - loss: 0.3898 - val_accuracy: 0.6531 - val_loss: 1.0394
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8699 - loss: 0.3711 - val_accuracy: 0.6939 - val_loss: 1.0876
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8014 - loss: 0.4141 - val_accuracy: 0.6939 - val_loss: 1.1407
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8356 - loss: 0.4366 - val_accuracy: 0.6939 - val_loss: 1.2161
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8082 - loss: 0.4526 - val_accuracy: 0.6939 - val_loss: 1.1582
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8699 - loss: 0.3660 - val_accuracy: 0.6531 - val_loss: 1.0964
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8288 - loss: 0.4428 - val_accuracy: 0.6531 - val_loss: 1.0149
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8014 - loss: 0.4379 - val_accuracy: 0.6531 - val_loss: 0.9885
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8836 - loss: 0.3596 - val_accuracy: 0.6531 - val_loss: 1.0572
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8356 - loss: 0.3547 - val_accuracy: 0.6327 - val_loss: 1.1562
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8219 - loss: 0.4035 - val_accuracy: 0.6531 - val_loss: 1.1933
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8767 - loss: 0.3446 - val_accuracy: 0.6531 - val_loss: 1.1371
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8219 - loss: 0.3387 - val_accuracy: 0.6122 - val_loss: 1.0820
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8425 - loss: 0.3839 - val_accuracy: 0.6939 - val_loss: 1.0438
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8630 - loss: 0.3598 - val_accuracy: 0.6939 - val_loss: 1.0695
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8630 - loss: 0.3520 - val_accuracy: 0.6939 - val_loss: 1.1577
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8425 - loss: 0.4223 - val_accuracy: 0.6735 - val_loss: 1.2481
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8630 - loss: 0.3431 - val_accuracy: 0.6735 - val_loss: 1.2892
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8288 - loss: 0.3445 - val_accuracy: 0.6531 - val_loss: 1.2926
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8151 - loss: 0.3805 - val_accuracy: 0.5102 - val_loss: 1.2159
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8562 - loss: 0.2935 - val_accuracy: 0.5714 - val_loss: 1.0689
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8356 - loss: 0.4425 - val_accuracy: 0.6122 - val_loss: 0.9311
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8425 - loss: 0.3847 - val_accuracy: 0.6735 - val_loss: 0.8540
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8630 - loss: 0.3385 - val_accuracy: 0.7143 - val_loss: 0.7955
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8219 - loss: 0.4600 - val_accuracy: 0.7347 - val_loss: 0.7449
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8425 - loss: 0.4166 - val_accuracy: 0.7755 - val_loss: 0.7399
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8562 - loss: 0.2913 - val_accuracy: 0.6939 - val_loss: 0.7892
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8356 - loss: 0.3512 - val_accuracy: 0.7347 - val_loss: 0.8010
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8767 - loss: 0.3214 - val_accuracy: 0.7143 - val_loss: 0.8275
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8973 - loss: 0.2915 - val_accuracy: 0.7347 - val_loss: 0.8518
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8356 - loss: 0.3537 - val_accuracy: 0.7959 - val_loss: 0.8809
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8630 - loss: 0.3515 - val_accuracy: 0.7551 - val_loss: 0.9214
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8699 - loss: 0.2970 - val_accuracy: 0.7551 - val_loss: 0.8542
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8219 - loss: 0.3853 - val_accuracy: 0.6939 - val_loss: 0.7872
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8767 - loss: 0.3083 - val_accuracy: 0.6735 - val_loss: 0.8012
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8973 - loss: 0.3082 - val_accuracy: 0.6735 - val_loss: 0.8448
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8973 - loss: 0.2594 - val_accuracy: 0.6735 - val_loss: 0.9279
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9110 - loss: 0.2784 - val_accuracy: 0.5918 - val_loss: 1.0244
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8493 - loss: 0.3465 - val_accuracy: 0.6122 - val_loss: 1.1005
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9110 - loss: 0.2321 - val_accuracy: 0.6327 - val_loss: 1.0899
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8973 - loss: 0.2945 - val_accuracy: 0.6735 - val_loss: 1.1157
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8767 - loss: 0.3438 - val_accuracy: 0.6327 - val_loss: 1.0908
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8288 - loss: 0.3549 - val_accuracy: 0.6735 - val_loss: 0.9031
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8219 - loss: 0.4226 - val_accuracy: 0.6531 - val_loss: 0.9423
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8493 - loss: 0.3711 - val_accuracy: 0.6735 - val_loss: 0.9057
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8836 - loss: 0.3259 - val_accuracy: 0.6735 - val_loss: 0.9003
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8904 - loss: 0.3178 - val_accuracy: 0.6122 - val_loss: 0.9010
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8836 - loss: 0.3100 - val_accuracy: 0.5918 - val_loss: 0.8665
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8562 - loss: 0.3970 - val_accuracy: 0.6327 - val_loss: 0.8913
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8630 - loss: 0.3093 - val_accuracy: 0.6122 - val_loss: 1.0304
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8767 - loss: 0.2824 - val_accuracy: 0.5918 - val_loss: 1.0025
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8904 - loss: 0.3151 - val_accuracy: 0.6939 - val_loss: 0.9018
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8767 - loss: 0.2710 - val_accuracy: 0.6735 - val_loss: 0.8655
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8562 - loss: 0.3806 - val_accuracy: 0.6939 - val_loss: 0.7918
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8973 - loss: 0.2581 - val_accuracy: 0.6939 - val_loss: 0.7479
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8493 - loss: 0.2862 - val_accuracy: 0.7347 - val_loss: 0.7380
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8767 - loss: 0.3039 - val_accuracy: 0.7347 - val_loss: 0.6961
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8630 - loss: 0.3391 - val_accuracy: 0.7347 - val_loss: 0.7290
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8699 - loss: 0.3568 - val_accuracy: 0.6939 - val_loss: 0.8059
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9041 - loss: 0.2441 - val_accuracy: 0.6735 - val_loss: 0.8929
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8630 - loss: 0.3380 - val_accuracy: 0.6735 - val_loss: 0.9164
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8562 - loss: 0.3387 - val_accuracy: 0.6531 - val_loss: 0.8743
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8767 - loss: 0.3061 - val_accuracy: 0.6735 - val_loss: 0.8421
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8767 - loss: 0.2617 - val_accuracy: 0.6735 - val_loss: 0.8257
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8562 - loss: 0.3544 - val_accuracy: 0.6735 - val_loss: 0.8011
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8562 - loss: 0.3234 - val_accuracy: 0.6939 - val_loss: 0.8111
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8836 - loss: 0.2753 - val_accuracy: 0.7143 - val_loss: 0.8108
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8973 - loss: 0.2658 - val_accuracy: 0.6939 - val_loss: 0.8159
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9041 - loss: 0.2437 - val_accuracy: 0.7143 - val_loss: 0.7771
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8973 - loss: 0.2626 - val_accuracy: 0.7551 - val_loss: 0.7230
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8973 - loss: 0.3291 - val_accuracy: 0.7143 - val_loss: 0.7128
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9178 - loss: 0.2600 - val_accuracy: 0.6531 - val_loss: 0.7515
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9247 - loss: 0.2236 - val_accuracy: 0.6531 - val_loss: 0.8292
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8562 - loss: 0.2836 - val_accuracy: 0.6531 - val_loss: 0.8314
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.2044 - val_accuracy: 0.6735 - val_loss: 0.8196
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8836 - loss: 0.3297 - val_accuracy: 0.6327 - val_loss: 0.8904
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9041 - loss: 0.2230 - val_accuracy: 0.6327 - val_loss: 0.9701
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8562 - loss: 0.3451 - val_accuracy: 0.6531 - val_loss: 0.9206
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8973 - loss: 0.2404 - val_accuracy: 0.7347 - val_loss: 0.8247
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8767 - loss: 0.2587 - val_accuracy: 0.7959 - val_loss: 0.7424
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8904 - loss: 0.2890 - val_accuracy: 0.7959 - val_loss: 0.6960
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8836 - loss: 0.2500 - val_accuracy: 0.6939 - val_loss: 0.7078
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8767 - loss: 0.2325 - val_accuracy: 0.6939 - val_loss: 0.8251
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9041 - loss: 0.2596 - val_accuracy: 0.6939 - val_loss: 0.7159
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9041 - loss: 0.2291 - val_accuracy: 0.7959 - val_loss: 0.6427
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9110 - loss: 0.2297 - val_accuracy: 0.7755 - val_loss: 0.6727
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9247 - loss: 0.2242 - val_accuracy: 0.7551 - val_loss: 0.7150
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9178 - loss: 0.2414 - val_accuracy: 0.7347 - val_loss: 0.7431
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9041 - loss: 0.2069 - val_accuracy: 0.6939 - val_loss: 0.7794
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9110 - loss: 0.1999 - val_accuracy: 0.6939 - val_loss: 0.6901
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9041 - loss: 0.2714 - val_accuracy: 0.7755 - val_loss: 0.5884
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9247 - loss: 0.2352 - val_accuracy: 0.7959 - val_loss: 0.5466
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8767 - loss: 0.2654 - val_accuracy: 0.7551 - val_loss: 0.6057
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8836 - loss: 0.2208 - val_accuracy: 0.6939 - val_loss: 0.7655
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9041 - loss: 0.2368 - val_accuracy: 0.6531 - val_loss: 0.8771
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8836 - loss: 0.2686 - val_accuracy: 0.6531 - val_loss: 0.9066
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8562 - loss: 0.3352 - val_accuracy: 0.6939 - val_loss: 0.7986
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8973 - loss: 0.2466 - val_accuracy: 0.7755 - val_loss: 0.6751
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8699 - loss: 0.3062 - val_accuracy: 0.6735 - val_loss: 0.7169
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8836 - loss: 0.2495 - val_accuracy: 0.7143 - val_loss: 0.6438
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9247 - loss: 0.1701 - val_accuracy: 0.7551 - val_loss: 0.6259
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9041 - loss: 0.2224 - val_accuracy: 0.7347 - val_loss: 0.6037
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9178 - loss: 0.2382 - val_accuracy: 0.7347 - val_loss: 0.6420
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9315 - loss: 0.2113 - val_accuracy: 0.7143 - val_loss: 0.7007
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8904 - loss: 0.2448 - val_accuracy: 0.7143 - val_loss: 0.7609
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9110 - loss: 0.2208 - val_accuracy: 0.7143 - val_loss: 0.7493
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9110 - loss: 0.1976 - val_accuracy: 0.7347 - val_loss: 0.7220
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9247 - loss: 0.2130 - val_accuracy: 0.7551 - val_loss: 0.6902
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9178 - loss: 0.1701 - val_accuracy: 0.7143 - val_loss: 0.7288
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9041 - loss: 0.1785 - val_accuracy: 0.7143 - val_loss: 0.7572
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9247 - loss: 0.1600 - val_accuracy: 0.7143 - val_loss: 0.7213
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8836 - loss: 0.2618 - val_accuracy: 0.7347 - val_loss: 0.6579
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9384 - loss: 0.1607 - val_accuracy: 0.7959 - val_loss: 0.6444
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1988 - val_accuracy: 0.7755 - val_loss: 0.6584
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9315 - loss: 0.1503 - val_accuracy: 0.7755 - val_loss: 0.7438
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9247 - loss: 0.2178 - val_accuracy: 0.7143 - val_loss: 0.8921
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9041 - loss: 0.2334 - val_accuracy: 0.7347 - val_loss: 0.9135
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8904 - loss: 0.2834 - val_accuracy: 0.7551 - val_loss: 0.7353
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9452 - loss: 0.1546 - val_accuracy: 0.7755 - val_loss: 0.6369
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1835 - val_accuracy: 0.7755 - val_loss: 0.6409
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9247 - loss: 0.1899 - val_accuracy: 0.7551 - val_loss: 0.7230
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9589 - loss: 0.1651 - val_accuracy: 0.7551 - val_loss: 0.8276
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8836 - loss: 0.2846 - val_accuracy: 0.7551 - val_loss: 0.8029
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9452 - loss: 0.1637 - val_accuracy: 0.7347 - val_loss: 0.7153
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9247 - loss: 0.1598 - val_accuracy: 0.7347 - val_loss: 0.7985
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9178 - loss: 0.2034 - val_accuracy: 0.7347 - val_loss: 0.9629
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9521 - loss: 0.1512 - val_accuracy: 0.7143 - val_loss: 0.9321
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9247 - loss: 0.1778 - val_accuracy: 0.7143 - val_loss: 0.7979
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9521 - loss: 0.1432 - val_accuracy: 0.7551 - val_loss: 0.7221
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9110 - loss: 0.1482 - val_accuracy: 0.7959 - val_loss: 0.7019
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9247 - loss: 0.1755 - val_accuracy: 0.7959 - val_loss: 0.6520
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9041 - loss: 0.2243 - val_accuracy: 0.7959 - val_loss: 0.6579
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9178 - loss: 0.1907 - val_accuracy: 0.6939 - val_loss: 0.7810
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9384 - loss: 0.1724 - val_accuracy: 0.6939 - val_loss: 0.8938
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9384 - loss: 0.1613 - val_accuracy: 0.7143 - val_loss: 0.8130
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9384 - loss: 0.1540 - val_accuracy: 0.7347 - val_loss: 0.8892
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9384 - loss: 0.1460 - val_accuracy: 0.7347 - val_loss: 0.7940
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9384 - loss: 0.1306 - val_accuracy: 0.7551 - val_loss: 0.7469
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9452 - loss: 0.1576 - val_accuracy: 0.7347 - val_loss: 0.8662
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1484 - val_accuracy: 0.7347 - val_loss: 1.1053
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9110 - loss: 0.2073 - val_accuracy: 0.7347 - val_loss: 1.1077
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9110 - loss: 0.1712 - val_accuracy: 0.7347 - val_loss: 0.9018
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9452 - loss: 0.1359 - val_accuracy: 0.7755 - val_loss: 0.7420
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9041 - loss: 0.2263 - val_accuracy: 0.7347 - val_loss: 0.8961
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.1115 - val_accuracy: 0.7143 - val_loss: 1.0755
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.1386 - val_accuracy: 0.7347 - val_loss: 0.9758
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8973 - loss: 0.2765 - val_accuracy: 0.8367 - val_loss: 0.4935
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8836 - loss: 0.3071 - val_accuracy: 0.8163 - val_loss: 0.4767
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8836 - loss: 0.2718 - val_accuracy: 0.7959 - val_loss: 0.6118
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8973 - loss: 0.2259 - val_accuracy: 0.7347 - val_loss: 0.9767
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9247 - loss: 0.2165 - val_accuracy: 0.7347 - val_loss: 1.0638
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9315 - loss: 0.2435 - val_accuracy: 0.7959 - val_loss: 0.8433
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1927 - val_accuracy: 0.8163 - val_loss: 0.7639
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9110 - loss: 0.2358 - val_accuracy: 0.8163 - val_loss: 0.7330
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9110 - loss: 0.1643 - val_accuracy: 0.8367 - val_loss: 0.7921
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1728 - val_accuracy: 0.7551 - val_loss: 1.0030
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9384 - loss: 0.1518 - val_accuracy: 0.7551 - val_loss: 0.9600
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9178 - loss: 0.2081 - val_accuracy: 0.7959 - val_loss: 0.7182
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9110 - loss: 0.2380 - val_accuracy: 0.8367 - val_loss: 0.5632
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9178 - loss: 0.1815 - val_accuracy: 0.8367 - val_loss: 0.5828
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9178 - loss: 0.2264 - val_accuracy: 0.7959 - val_loss: 0.7216
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9384 - loss: 0.1776 - val_accuracy: 0.7551 - val_loss: 0.8501
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9384 - loss: 0.1809 - val_accuracy: 0.7347 - val_loss: 0.9052
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9521 - loss: 0.1506 - val_accuracy: 0.7959 - val_loss: 0.7336
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9452 - loss: 0.1402 - val_accuracy: 0.8367 - val_loss: 0.6552
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9384 - loss: 0.1495 - val_accuracy: 0.8163 - val_loss: 0.6434
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9247 - loss: 0.2049 - val_accuracy: 0.8163 - val_loss: 0.6659
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9178 - loss: 0.1478 - val_accuracy: 0.8367 - val_loss: 0.6919
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9247 - loss: 0.1741 - val_accuracy: 0.8367 - val_loss: 0.7027
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9589 - loss: 0.1574 - val_accuracy: 0.7959 - val_loss: 0.7301
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.1045 - val_accuracy: 0.7959 - val_loss: 0.7532
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9452 - loss: 0.1473 - val_accuracy: 0.7551 - val_loss: 0.8193
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9384 - loss: 0.1559 - val_accuracy: 0.7551 - val_loss: 0.8149
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9452 - loss: 0.1403 - val_accuracy: 0.7347 - val_loss: 0.8272
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9315 - loss: 0.1881 - val_accuracy: 0.7551 - val_loss: 0.8236
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9247 - loss: 0.1716 - val_accuracy: 0.7755 - val_loss: 0.7961
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.1261 - val_accuracy: 0.7347 - val_loss: 0.9306
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9521 - loss: 0.1292 - val_accuracy: 0.7347 - val_loss: 0.9688
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9521 - loss: 0.1406 - val_accuracy: 0.7755 - val_loss: 0.8071
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9726 - loss: 0.1241 - val_accuracy: 0.8163 - val_loss: 0.6704
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9521 - loss: 0.1189 - val_accuracy: 0.8163 - val_loss: 0.6769
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9384 - loss: 0.1261 - val_accuracy: 0.7551 - val_loss: 0.7541
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9452 - loss: 0.1364 - val_accuracy: 0.7347 - val_loss: 0.9147
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9041 - loss: 0.2001 - val_accuracy: 0.7755 - val_loss: 0.7619
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1448 - val_accuracy: 0.8571 - val_loss: 0.5416
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9247 - loss: 0.1571 - val_accuracy: 0.8571 - val_loss: 0.5581
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9521 - loss: 0.1533 - val_accuracy: 0.8367 - val_loss: 0.6596
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1216 - val_accuracy: 0.7551 - val_loss: 0.9176
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9110 - loss: 0.1812 - val_accuracy: 0.7551 - val_loss: 0.8842
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1219 - val_accuracy: 0.8367 - val_loss: 0.7213
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9452 - loss: 0.1084 - val_accuracy: 0.8163 - val_loss: 0.6417
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9247 - loss: 0.1485 - val_accuracy: 0.8163 - val_loss: 0.6622
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9110 - loss: 0.2258 - val_accuracy: 0.7755 - val_loss: 0.8656
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9589 - loss: 0.1083 - val_accuracy: 0.7347 - val_loss: 1.1567
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9315 - loss: 0.2012 - val_accuracy: 0.7347 - val_loss: 0.8750
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9384 - loss: 0.1519 - val_accuracy: 0.8571 - val_loss: 0.5556
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9315 - loss: 0.1724 - val_accuracy: 0.8776 - val_loss: 0.4686
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9315 - loss: 0.2405 - val_accuracy: 0.8571 - val_loss: 0.5188
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1609 - val_accuracy: 0.8367 - val_loss: 0.6299
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9658 - loss: 0.0998 - val_accuracy: 0.8163 - val_loss: 0.7238
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9521 - loss: 0.0995 - val_accuracy: 0.8163 - val_loss: 0.6951
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9726 - loss: 0.0923 - val_accuracy: 0.8367 - val_loss: 0.6113
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9384 - loss: 0.1388 - val_accuracy: 0.8163 - val_loss: 0.5507
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9384 - loss: 0.1431 - val_accuracy: 0.8163 - val_loss: 0.5780
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9452 - loss: 0.1211 - val_accuracy: 0.7959 - val_loss: 0.6834
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9384 - loss: 0.1330 - val_accuracy: 0.7959 - val_loss: 0.7785
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9589 - loss: 0.0904 - val_accuracy: 0.7959 - val_loss: 0.8280
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9452 - loss: 0.1374 - val_accuracy: 0.7959 - val_loss: 0.7995
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9521 - loss: 0.1181 - val_accuracy: 0.7959 - val_loss: 0.8090
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9521 - loss: 0.0955 - val_accuracy: 0.7959 - val_loss: 0.7439
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9589 - loss: 0.0944 - val_accuracy: 0.7959 - val_loss: 0.7054
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9726 - loss: 0.0825 - val_accuracy: 0.8163 - val_loss: 0.7128
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1333 - val_accuracy: 0.8163 - val_loss: 0.7772
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.0978 - val_accuracy: 0.8163 - val_loss: 0.7522
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9726 - loss: 0.0672 - val_accuracy: 0.8367 - val_loss: 0.6370
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9452 - loss: 0.1166 - val_accuracy: 0.8571 - val_loss: 0.5881
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9589 - loss: 0.1011 - val_accuracy: 0.8571 - val_loss: 0.5656
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9452 - loss: 0.1405 - val_accuracy: 0.8367 - val_loss: 0.6472
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9658 - loss: 0.1020 - val_accuracy: 0.8163 - val_loss: 0.7400
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.0983 - val_accuracy: 0.8163 - val_loss: 0.7854
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1336 - val_accuracy: 0.8367 - val_loss: 0.6836
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9384 - loss: 0.1412 - val_accuracy: 0.8571 - val_loss: 0.6244
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1328 - val_accuracy: 0.8571 - val_loss: 0.6529
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.0954 - val_accuracy: 0.7959 - val_loss: 0.8469
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9726 - loss: 0.0705 - val_accuracy: 0.7347 - val_loss: 1.0007
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9589 - loss: 0.1387 - val_accuracy: 0.7959 - val_loss: 0.7995
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9315 - loss: 0.1164 - val_accuracy: 0.8163 - val_loss: 0.7084
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9452 - loss: 0.1021 - val_accuracy: 0.8367 - val_loss: 0.7204
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9658 - loss: 0.0905 - val_accuracy: 0.8163 - val_loss: 0.7390
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9658 - loss: 0.0911 - val_accuracy: 0.8571 - val_loss: 0.7381
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9521 - loss: 0.1039 - val_accuracy: 0.8367 - val_loss: 0.7363
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9589 - loss: 0.1266 - val_accuracy: 0.8163 - val_loss: 0.7286
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9452 - loss: 0.1334 - val_accuracy: 0.8776 - val_loss: 0.6684
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9452 - loss: 0.1402 - val_accuracy: 0.8367 - val_loss: 0.7142
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.1004 - val_accuracy: 0.8367 - val_loss: 0.7831
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9726 - loss: 0.0896 - val_accuracy: 0.8367 - val_loss: 0.8508
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9452 - loss: 0.1191 - val_accuracy: 0.8367 - val_loss: 0.7708
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9726 - loss: 0.0803 - val_accuracy: 0.8571 - val_loss: 0.6872
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9521 - loss: 0.0850 - val_accuracy: 0.8367 - val_loss: 0.6897
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1390 - val_accuracy: 0.8163 - val_loss: 0.7029
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9658 - loss: 0.0850 - val_accuracy: 0.8163 - val_loss: 0.7014
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9795 - loss: 0.0629 - val_accuracy: 0.8367 - val_loss: 0.7167
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.0863 - val_accuracy: 0.8367 - val_loss: 0.6546
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.1235 - val_accuracy: 0.8776 - val_loss: 0.5666
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9658 - loss: 0.0972 - val_accuracy: 0.8980 - val_loss: 0.5235
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9795 - loss: 0.0922 - val_accuracy: 0.8980 - val_loss: 0.5565
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9795 - loss: 0.0647 - val_accuracy: 0.8776 - val_loss: 0.5889
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9452 - loss: 0.1447 - val_accuracy: 0.8571 - val_loss: 0.6973
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9726 - loss: 0.0524 - val_accuracy: 0.8367 - val_loss: 0.8175
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9315 - loss: 0.1276 - val_accuracy: 0.8163 - val_loss: 0.7988
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9589 - loss: 0.0906 - val_accuracy: 0.8367 - val_loss: 0.7002
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.0973 - val_accuracy: 0.8571 - val_loss: 0.6260
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9521 - loss: 0.1240 - val_accuracy: 0.8571 - val_loss: 0.6332
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1214 - val_accuracy: 0.8367 - val_loss: 0.7167
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9178 - loss: 0.1204 - val_accuracy: 0.7959 - val_loss: 0.9238
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9452 - loss: 0.1341 - val_accuracy: 0.7959 - val_loss: 0.9086
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.0792 - val_accuracy: 0.8367 - val_loss: 0.7707
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9589 - loss: 0.1108 - val_accuracy: 0.8367 - val_loss: 0.5702
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9384 - loss: 0.1212 - val_accuracy: 0.8367 - val_loss: 0.5084
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9726 - loss: 0.0867 - val_accuracy: 0.8163 - val_loss: 0.6139
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9384 - loss: 0.1390 - val_accuracy: 0.7959 - val_loss: 0.5904
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9726 - loss: 0.1035 - val_accuracy: 0.8163 - val_loss: 0.5296
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9658 - loss: 0.0826 - val_accuracy: 0.8776 - val_loss: 0.5065
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9452 - loss: 0.1699 - val_accuracy: 0.8571 - val_loss: 0.5757
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1097 - val_accuracy: 0.8367 - val_loss: 0.6305
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9521 - loss: 0.1167 - val_accuracy: 0.8571 - val_loss: 0.5306
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9589 - loss: 0.1356 - val_accuracy: 0.8776 - val_loss: 0.4294
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9589 - loss: 0.0923 - val_accuracy: 0.8776 - val_loss: 0.4214
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1165 - val_accuracy: 0.8776 - val_loss: 0.4560
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9452 - loss: 0.1435 - val_accuracy: 0.8367 - val_loss: 0.6204
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.0764 - val_accuracy: 0.8367 - val_loss: 0.6216
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9452 - loss: 0.1193 - val_accuracy: 0.8571 - val_loss: 0.4896
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1280 - val_accuracy: 0.8776 - val_loss: 0.4306
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9589 - loss: 0.0852 - val_accuracy: 0.8776 - val_loss: 0.4370
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9452 - loss: 0.1190 - val_accuracy: 0.8776 - val_loss: 0.4522
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9726 - loss: 0.0814 - val_accuracy: 0.8571 - val_loss: 0.4662
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9726 - loss: 0.0661 - val_accuracy: 0.8776 - val_loss: 0.4790
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9521 - loss: 0.0862 - val_accuracy: 0.8776 - val_loss: 0.4862
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9658 - loss: 0.1051 - val_accuracy: 0.8571 - val_loss: 0.5383
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9658 - loss: 0.0783 - val_accuracy: 0.8163 - val_loss: 0.6352
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9795 - loss: 0.0765 - val_accuracy: 0.8367 - val_loss: 0.7263
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9658 - loss: 0.1030 - val_accuracy: 0.8367 - val_loss: 0.7175
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.0919 - val_accuracy: 0.8367 - val_loss: 0.5590
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.0887 - val_accuracy: 0.8980 - val_loss: 0.4932
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9384 - loss: 0.1553 - val_accuracy: 0.8367 - val_loss: 0.7516
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.1117 - val_accuracy: 0.6939 - val_loss: 1.3965
# Epoch 368/1000
# ...
# Epoch 884/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9184 - val_loss: 0.5842
# Epoch 885/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9184 - val_loss: 0.5987
# Epoch 886/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0298 - val_accuracy: 0.9184 - val_loss: 0.5156
# Epoch 887/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9184 - val_loss: 0.4144
# Epoch 888/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9184 - val_loss: 0.3203
# Epoch 889/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9388 - val_loss: 0.2550
# Epoch 890/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9592 - val_loss: 0.2269
# Epoch 891/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9796 - val_loss: 0.2113
# Epoch 892/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9932 - loss: 0.0278 - val_accuracy: 0.9796 - val_loss: 0.2063
# Epoch 893/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9796 - val_loss: 0.2046
# Epoch 894/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9796 - val_loss: 0.2106
# Epoch 895/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9592 - val_loss: 0.2254
# Epoch 896/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9592 - val_loss: 0.2426
# Epoch 897/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0145 - val_accuracy: 0.9388 - val_loss: 0.2533
# Epoch 898/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9388 - val_loss: 0.2616
# Epoch 899/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9932 - loss: 0.0134 - val_accuracy: 0.9388 - val_loss: 0.2582
# Epoch 900/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9388 - val_loss: 0.2534
# Epoch 901/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0185 - val_accuracy: 0.9388 - val_loss: 0.2560
# Epoch 902/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9863 - loss: 0.0218 - val_accuracy: 0.9388 - val_loss: 0.2732
# Epoch 903/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0127 - val_accuracy: 0.9388 - val_loss: 0.2853
# Epoch 904/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9388 - val_loss: 0.2974
# Epoch 905/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9388 - val_loss: 0.3190
# Epoch 906/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0212 - val_accuracy: 0.9388 - val_loss: 0.3211
# Epoch 907/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9863 - loss: 0.0402 - val_accuracy: 0.9388 - val_loss: 0.2861
# Epoch 908/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9388 - val_loss: 0.2546
# Epoch 909/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0177 - val_accuracy: 0.9388 - val_loss: 0.2272
# Epoch 910/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9795 - loss: 0.0281 - val_accuracy: 0.9592 - val_loss: 0.2336
# Epoch 911/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9592 - val_loss: 0.2437
# Epoch 912/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9863 - loss: 0.0373 - val_accuracy: 0.9388 - val_loss: 0.2524
# Epoch 913/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0374 - val_accuracy: 0.9388 - val_loss: 0.2508
# Epoch 914/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9932 - loss: 0.0161 - val_accuracy: 0.9388 - val_loss: 0.2488
# Epoch 915/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9863 - loss: 0.0403 - val_accuracy: 0.9388 - val_loss: 0.2512
# Epoch 916/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0103 - val_accuracy: 0.8980 - val_loss: 0.2704
# Epoch 917/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8980 - val_loss: 0.2926
# Epoch 918/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8980 - val_loss: 0.3135
# Epoch 919/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0081 - val_accuracy: 0.8980 - val_loss: 0.3208
# Epoch 920/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8980 - val_loss: 0.3209
# Epoch 921/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8980 - val_loss: 0.3190
# Epoch 922/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9932 - loss: 0.0214 - val_accuracy: 0.8980 - val_loss: 0.3077
# Epoch 923/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8980 - val_loss: 0.2997
# Epoch 924/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9184 - val_loss: 0.2960
# Epoch 925/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0092 - val_accuracy: 0.9388 - val_loss: 0.2938
# Epoch 926/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9388 - val_loss: 0.2955
# Epoch 927/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0432 - val_accuracy: 0.9388 - val_loss: 0.2970
# Epoch 928/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8980 - val_loss: 0.3219
# Epoch 929/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.8980 - val_loss: 0.3352
# Epoch 930/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8980 - val_loss: 0.3636
# Epoch 931/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0142 - val_accuracy: 0.9184 - val_loss: 0.3920
# Epoch 932/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9932 - loss: 0.0244 - val_accuracy: 0.9184 - val_loss: 0.4297
# Epoch 933/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 9.9640e-04 - val_accuracy: 0.8980 - val_loss: 0.5015
# Epoch 934/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9932 - loss: 0.0212 - val_accuracy: 0.8980 - val_loss: 0.5807
# Epoch 935/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9658 - loss: 0.1233 - val_accuracy: 0.9184 - val_loss: 0.4557
# Epoch 936/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0092 - val_accuracy: 0.9184 - val_loss: 0.4140
# Epoch 937/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.8980 - val_loss: 0.4092
# Epoch 938/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9795 - loss: 0.0494 - val_accuracy: 0.8980 - val_loss: 0.3587
# Epoch 939/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9863 - loss: 0.0376 - val_accuracy: 0.9184 - val_loss: 0.3077
# Epoch 940/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9184 - val_loss: 0.2854
# Epoch 941/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9388 - val_loss: 0.2616
# Epoch 942/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9863 - loss: 0.0443 - val_accuracy: 0.9184 - val_loss: 0.2480
# Epoch 943/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9863 - loss: 0.0281 - val_accuracy: 0.9388 - val_loss: 0.2218
# Epoch 944/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0182 - val_accuracy: 0.9388 - val_loss: 0.1884
# Epoch 945/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0311 - val_accuracy: 0.9592 - val_loss: 0.1315
# Epoch 946/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9388 - val_loss: 0.1820
# Epoch 947/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9863 - loss: 0.0519 - val_accuracy: 0.9388 - val_loss: 0.1957
# Epoch 948/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0333 - val_accuracy: 0.9592 - val_loss: 0.1607
# Epoch 949/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9592 - val_loss: 0.1551
# Epoch 950/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9863 - loss: 0.0363 - val_accuracy: 0.9388 - val_loss: 0.1743
# Epoch 951/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0159 - val_accuracy: 0.9388 - val_loss: 0.1976
# Epoch 952/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0339 - val_accuracy: 0.9388 - val_loss: 0.2405
# Epoch 953/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9932 - loss: 0.0680 - val_accuracy: 0.9388 - val_loss: 0.2397
# Epoch 954/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9863 - loss: 0.0300 - val_accuracy: 0.9388 - val_loss: 0.1727
# Epoch 955/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9592 - val_loss: 0.1181
# Epoch 956/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9932 - loss: 0.0257 - val_accuracy: 0.9388 - val_loss: 0.1285
# Epoch 957/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9388 - val_loss: 0.1496
# Epoch 958/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9592 - val_loss: 0.1641
# Epoch 959/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9592 - val_loss: 0.1740
# Epoch 960/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 7.4887e-04 - val_accuracy: 0.9592 - val_loss: 0.1836
# Epoch 961/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9592 - val_loss: 0.1905
# Epoch 962/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9592 - val_loss: 0.1922
# Epoch 963/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0159 - val_accuracy: 0.9796 - val_loss: 0.1932
# Epoch 964/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9863 - loss: 0.0184 - val_accuracy: 0.9796 - val_loss: 0.1860
# Epoch 965/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9932 - loss: 0.0165 - val_accuracy: 0.9796 - val_loss: 0.1719
# Epoch 966/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9796 - val_loss: 0.1607
# Epoch 967/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9796 - val_loss: 0.1559
# Epoch 968/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9863 - loss: 0.0451 - val_accuracy: 0.9592 - val_loss: 0.1538
# Epoch 969/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9388 - val_loss: 0.1555
# Epoch 970/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0167 - val_accuracy: 0.9388 - val_loss: 0.1636
# Epoch 971/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9388 - val_loss: 0.1859
# Epoch 972/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9932 - loss: 0.0163 - val_accuracy: 0.9184 - val_loss: 0.2152
# Epoch 973/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0117 - val_accuracy: 0.9184 - val_loss: 0.1996
# Epoch 974/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9863 - loss: 0.0260 - val_accuracy: 0.9388 - val_loss: 0.1846
# Epoch 975/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 9.3316e-04 - val_accuracy: 0.9388 - val_loss: 0.1889
# Epoch 976/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9388 - val_loss: 0.1971
# Epoch 977/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0100 - val_accuracy: 0.9388 - val_loss: 0.2046
# Epoch 978/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9388 - val_loss: 0.2128
# Epoch 979/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9388 - val_loss: 0.2207
# Epoch 980/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9932 - loss: 0.0095 - val_accuracy: 0.9388 - val_loss: 0.2276
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9932 - loss: 0.0183 - val_accuracy: 0.9388 - val_loss: 0.2392
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0231 - val_accuracy: 0.9388 - val_loss: 0.2381
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9388 - val_loss: 0.2375
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9388 - val_loss: 0.2348
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9388 - val_loss: 0.2335
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9388 - val_loss: 0.2337
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9388 - val_loss: 0.2338
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9932 - loss: 0.0065 - val_accuracy: 0.9388 - val_loss: 0.2374
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9388 - val_loss: 0.2435
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.1594e-04 - val_accuracy: 0.9388 - val_loss: 0.2577
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8980 - val_loss: 0.2800
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8980 - val_loss: 0.2972
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8980 - val_loss: 0.3087
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9184 - val_loss: 0.3106
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0069 - val_accuracy: 0.9184 - val_loss: 0.3146
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9184 - val_loss: 0.3265
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9932 - loss: 0.0115 - val_accuracy: 0.9184 - val_loss: 0.3377
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 7.4078e-04 - val_accuracy: 0.9184 - val_loss: 0.3468
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9184 - val_loss: 0.3553
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9184 - val_loss: 0.3610
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9728 - loss: 0.0653
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Confusion Matrix:
#  [[ 9  1  0  0  0]
#  [ 0 12  0  0  0]
#  [ 0  0 10  0  0]
#  [ 1  0  0  5  0]
#  [ 0  0  0  0 11]]
# Per-class accuracy:
# Label 0 accuracy: 90.0%
# Label 1 accuracy: 100.0%
# Label 2 accuracy: 100.0%
# Label 3 accuracy: 83.3%
# Label 4 accuracy: 100.0%
#
# Saved prediction results to 'prediction_results.xlsx'
#
# === Manual Prediction Inspection ===
# Sample index in df: 24
# Current date: 2023-11-09 00:00:00
# Future date: 2023-11-17 00:00:00
# Current price: 130.24
# Future price: 135.31
# Actual % change: 3.89%
# True label: 4 (actual movement class)
# Predicted label: 4

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import BorderlineSMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import tensorflow as tf

print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))

# === Parameters ===
time_steps = 40
forward_days = 6
classes = 5
max_samples = 30  # Maximum number of random samples to include in Excel

# === Load data ===
df = pd.read_csv('AAPL.csv', parse_dates=['Date'])
df = df.sort_values('Date').reset_index(drop=True)

# === Calculate indicators ===
df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
df['MACD'] = df['EMA12'] - df['EMA26']
df['MACD_signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
df['MACD_his'] = df['MACD'] - df['MACD_signal']

df.dropna(inplace=True)
df = df.reset_index(drop=True)

# === Feature selection ===
features = ['Open', 'High', 'Low', 'Close', 'Volume', 
            'MA10', 'MA20', 'MA50', 'MACD_ml', 'MACD_his', 
            'RSI14', 'OBV', 'ATR', 'StochasticMomentum']

# Make sure these columns exist or calculate them beforehand.
# For now, let's check and create missing columns with zeros to avoid errors:
for feat in features:
    if feat not in df.columns:
        df[feat] = 0.0

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[features])

# === Create supervised samples ===
X, y = [], []
for i in range(len(scaled_data) - time_steps - forward_days):
    X.append(scaled_data[i:i+time_steps])
    
    current_price = df['Close'].iloc[i+time_steps-1]
    future_price = df['Close'].iloc[i+time_steps+forward_days-1]
    pct_change = (future_price - current_price) / current_price * 100
    
    if pct_change <= -2:
        label = 0  # Big drop
    elif -2 < pct_change <= -0.5:
        label = 1  # Small drop
    elif -0.5 < pct_change < 0.5:
        label = 2  # Neutral
    elif 0.5 <= pct_change < 2:
        label = 3  # Small rise
    else:
        label = 4  # Big rise
        
    y.append(label)

X, y = np.array(X), np.array(y)

# === Apply BorderlineSMOTE ONLY on X and y ===
X_flat = X.reshape(X.shape[0], -1)
X_resampled, y_resampled = BorderlineSMOTE(kind='borderline-2').fit_resample(X_flat, y)
X_resampled = X_resampled.reshape(-1, time_steps, len(features))

# === Train-test split ===
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.25, random_state=42)

# === Define model ===
def Create_LSTM_Model(units=1000, drop_out=0.5, lr=5e-4):
    model = Sequential()
    model.add(LSTM(units=units, input_shape=(time_steps, len(features)), return_sequences=True))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(LSTM(units=units))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=units, activation='tanh'))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=5, activation='softmax'))
    
    model.compile(optimizer=Adam(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# === Train model ===
model = Create_LSTM_Model()

from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=1000, batch_size=512, validation_data=(X_test, y_test), callbacks=[early_stop])

# === Evaluate model ===
model.evaluate(X_test, y_test)
y_pred = np.argmax(model.predict(X_test), axis=1)
conf_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_mat)

from collections import Counter
counts_origin = Counter(y_test)
unique_labels = np.unique(y_test)

print("Per-class accuracy:")
for i in unique_labels:
    if i < conf_mat.shape[0] and i < conf_mat.shape[1]:
        correct = conf_mat[i, i]
        total = sum(conf_mat[i, :])
        acc = 100 * correct / total if total > 0 else 0
        print(f"Label {i} accuracy: {acc:.1f}%")
    else:
        print(f"Label {i} not present in confusion matrix")

# === Map test samples back to original indices where possible ===
X_flat_original = X.reshape(X.shape[0], -1)

idx_test = []
for test_sample in X_test.reshape(X_test.shape[0], -1):
    matches = np.where((X_flat_original == test_sample).all(axis=1))[0]
    if len(matches) > 0:
        idx_test.append(matches[0])
    else:
        idx_test.append(-1)  # synthetic sample

idx_test = np.array(idx_test)

# === Randomly select indices for comparison ===
np.random.seed()  # Ensure randomness each run
non_synthetic_indices = np.where(idx_test != -1)[0]
random_indices = np.random.choice(non_synthetic_indices, size=min(max_samples, len(non_synthetic_indices)), replace=False)

# === Create a DataFrame with predictions and actual values for random dates ===
results = []
for i in random_indices:
    original_idx = idx_test[i]
    current_price = df.iloc[original_idx + time_steps - 1]['Close']
    future_price = df.iloc[original_idx + time_steps + forward_days - 1]['Close']
    actual_pct_change = (future_price - current_price) / current_price * 100
    predicted_label = y_pred[i]
    true_label = y_test[i]

    results.append({
        'Current_Date': df.iloc[original_idx + time_steps - 1]['Date'],
        'Future_Date': df.iloc[original_idx + time_steps + forward_days - 1]['Date'],
        'Current_Price': current_price,
        'Future_Price': future_price,
        'Predicted_Label': predicted_label,
        'True_Label': true_label,
        'Actual_Pct_Change': actual_pct_change
    })

results_df = pd.DataFrame(results)

# Save to Excel
results_df.to_excel('prediction_results_aapl.xlsx', index=False)

print("\nSaved prediction results to 'prediction_results_aapl.xlsx'")

# === Manual inspection example for one random test sample (non-synthetic) ===
if len(random_indices) > 0:
    sample_i = random_indices[0]
    original_df_index = idx_test[sample_i]

    print("\n=== Manual Prediction Inspection ===")
    print(f"Sample index in df: {original_df_index}")
    print("Current date:", df.iloc[original_df_index + time_steps - 1]['Date'])
    print("Future date:", df.iloc[original_df_index + time_steps + forward_days - 1]['Date'])
    print("Current price:", df.iloc[original_df_index + time_steps - 1]['Close'])
    print("Future price:", df.iloc[original_df_index + time_steps + forward_days - 1]['Close'])
    print(f"Actual % change: {((df.iloc[original_df_index + time_steps + forward_days - 1]['Close'] - df.iloc[original_df_index + time_steps - 1]['Close']) / df.iloc[original_df_index + time_steps - 1]['Close']) * 100:.2f}%")
    print(f"True label: {y_test[sample_i]} (actual movement class)")
    print(f"Predicted label: {y_pred[sample_i]}")
else:
    print("No non-synthetic test samples found for manual inspection.")
# Out:
# Num GPUs Available: 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 21
#      18 max_samples = 30  # Maximum number of random samples to include in Excel
#      20 # === Load data ===
# ---> 21 df = pd.read_csv('AAPL.csv', parse_dates=['Date'])
#      22 df = df.sort_values('Date').reset_index(drop=True)
#      24 # === Calculate indicators ===
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AAPL.csv'

# %% [markdown]
# ## Combined script all stocks

# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from imblearn.over_sampling import BorderlineSMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
from collections import Counter
import tensorflow as tf

# GPU memory handling
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
tf.keras.backend.clear_session()
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))

# === Parameters ===
time_steps = 40
forward_days = 5
classes = 5
folder_path = "stocks"  # Pfad zum Ordner mit CSVs

# === Features ===
features = ['Open', 'High', 'Low', 'Close', 'Volume', 
            'MA10', 'MA20', 'MA50', 'MACD_ml', 'MACD_his', 
            'RSI14', 'OBV', 'ATR', 'StochasticMomentum']

X_all, y_all = [], []

# === Hilfsfunktion: Feature-Engineering ===
def process_stock(df):
    df = df.sort_values('Date').reset_index(drop=True)
    df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
    df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = df['EMA12'] - df['EMA26']
    df['MACD_signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
    df['MACD_his'] = df['MACD'] - df['MACD_signal']
    df.dropna(inplace=True)
    df = df.reset_index(drop=True)

    # Füge Dummy-Spalten hinzu, wenn du sie brauchst
    for f in features:
        if f not in df.columns:
            df[f] = 0.0

    # Skaliere nur die Features
    scaler = StandardScaler()
    scaled = scaler.fit_transform(df[features])

    X, y = [], []
    for i in range(len(scaled) - time_steps - forward_days):
        X.append(scaled[i:i+time_steps])
        curr = df['Close'].iloc[i+time_steps-1]
        future = df['Close'].iloc[i+time_steps+forward_days-1]
        pct = (future - curr) / curr * 100
        if pct <= -2:
            label = 0
        elif -2 < pct <= -0.5:
            label = 1
        elif -0.5 < pct < 0.5:
            label = 2
        elif 0.5 <= pct < 2:
            label = 3
        else:
            label = 4
        y.append(label)

    return np.array(X), np.array(y)

# === Alle Dateien im Ordner verarbeiten ===
for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        try:
            df = pd.read_csv(os.path.join(folder_path, file), parse_dates=['Date'])
            X_part, y_part = process_stock(df)
            if len(X_part) > 0:
                X_all.append(X_part)
                y_all.append(y_part)
                print(f"{file}: {len(X_part)} samples")
        except Exception as e:
            print(f"Fehler bei Datei {file}: {e}")

# === Kombinieren ===
X = np.vstack(X_all)
y = np.hstack(y_all)

# === Resampling ===
X_reshaped = X.reshape(X.shape[0], -1)
X_resampled, y_resampled = BorderlineSMOTE(kind='borderline-2').fit_resample(X_reshaped, y)
X_resampled = X_resampled.reshape(-1, time_steps, len(features))

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1, random_state=42)

# === Modell ===
def Create_LSTM_Model(units=128, drop_out=0.5, lr=5e-4):
    model = Sequential()
    model.add(LSTM(units=units, input_shape=(time_steps, len(features)), return_sequences=True))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(LSTM(units=units))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=units, activation='tanh'))
    model.add(Dropout(drop_out))
    model.add(BatchNormalization())
    model.add(Dense(units=5, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# === Training ===
model = Create_LSTM_Model()
history = model.fit(X_train, y_train, epochs=400, batch_size=256, validation_data=(X_test, y_test))

# === Evaluation ===
model.evaluate(X_test, y_test)
y_pred = np.argmax(model.predict(X_test), axis=1)
conf_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_mat)

print("Per-class accuracy:")
for i in np.unique(y_test):
    if i < conf_mat.shape[0]:
        acc = 100 * conf_mat[i, i] / sum(conf_mat[i]) if sum(conf_mat[i]) > 0 else 0
        print(f"Label {i} accuracy: {acc:.1f}%")
# Out:
# Num GPUs Available: 1
# NVDA.csv: 104 samples
# META.csv: 104 samples
# AMZN.csv: 104 samples
# HOOD.csv: 104 samples
# TSLA.csv: 104 samples
# GOOGL.csv: 104 samples
# PLTR.csv: 104 samples
# AAPL.csv: 104 samples
# UBER.csv: 104 samples
# GC=F.csv: 104 samples
# BTC-USD.csv: 194 samples
# MSFT.csv: 104 samples
# Epoch 1/400
# /opt/conda/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.2182 - loss: 2.1486 - val_accuracy: 0.2982 - val_loss: 1.5940
# Epoch 2/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2436 - loss: 2.0108 - val_accuracy: 0.2945 - val_loss: 1.5786
# Epoch 3/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2467 - loss: 1.9031 - val_accuracy: 0.3236 - val_loss: 1.5674
# Epoch 4/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2839 - loss: 1.8174 - val_accuracy: 0.3236 - val_loss: 1.5584
# Epoch 5/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2668 - loss: 1.8601 - val_accuracy: 0.3382 - val_loss: 1.5502
# Epoch 6/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3032 - loss: 1.7639 - val_accuracy: 0.3455 - val_loss: 1.5388
# Epoch 7/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3223 - loss: 1.7168 - val_accuracy: 0.3564 - val_loss: 1.5279
# Epoch 8/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2947 - loss: 1.7310 - val_accuracy: 0.3636 - val_loss: 1.5143
# Epoch 9/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3436 - loss: 1.6389 - val_accuracy: 0.3782 - val_loss: 1.4981
# Epoch 10/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3643 - loss: 1.6249 - val_accuracy: 0.3818 - val_loss: 1.4843
# Epoch 11/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3488 - loss: 1.6422 - val_accuracy: 0.3709 - val_loss: 1.4704
# Epoch 12/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3763 - loss: 1.5796 - val_accuracy: 0.3600 - val_loss: 1.4587
# Epoch 13/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3953 - loss: 1.5260 - val_accuracy: 0.3745 - val_loss: 1.4481
# Epoch 14/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3788 - loss: 1.5471 - val_accuracy: 0.3673 - val_loss: 1.4178
# Epoch 15/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3631 - loss: 1.5693 - val_accuracy: 0.4291 - val_loss: 1.4073
# Epoch 16/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3974 - loss: 1.4826 - val_accuracy: 0.4000 - val_loss: 1.3992
# Epoch 17/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4124 - loss: 1.4533 - val_accuracy: 0.3927 - val_loss: 1.3825
# Epoch 18/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4095 - loss: 1.4349 - val_accuracy: 0.4364 - val_loss: 1.3622
# Epoch 19/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4234 - loss: 1.4227 - val_accuracy: 0.4400 - val_loss: 1.3482
# Epoch 20/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4528 - loss: 1.3565 - val_accuracy: 0.4509 - val_loss: 1.3335
# Epoch 21/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4542 - loss: 1.3944 - val_accuracy: 0.4618 - val_loss: 1.3099
# Epoch 22/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4558 - loss: 1.3520 - val_accuracy: 0.4655 - val_loss: 1.2993
# Epoch 23/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4549 - loss: 1.3713 - val_accuracy: 0.4545 - val_loss: 1.3030
# Epoch 24/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4529 - loss: 1.3423 - val_accuracy: 0.4545 - val_loss: 1.2882
# Epoch 25/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4585 - loss: 1.3539 - val_accuracy: 0.4473 - val_loss: 1.2711
# Epoch 26/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4695 - loss: 1.2981 - val_accuracy: 0.4800 - val_loss: 1.2720
# Epoch 27/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4786 - loss: 1.2761 - val_accuracy: 0.5018 - val_loss: 1.2469
# Epoch 28/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4829 - loss: 1.2715 - val_accuracy: 0.5018 - val_loss: 1.2326
# Epoch 29/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4841 - loss: 1.2780 - val_accuracy: 0.5127 - val_loss: 1.2144
# Epoch 30/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4957 - loss: 1.2381 - val_accuracy: 0.5127 - val_loss: 1.2274
# Epoch 31/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5156 - loss: 1.2014 - val_accuracy: 0.5382 - val_loss: 1.1733
# Epoch 32/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5256 - loss: 1.1808 - val_accuracy: 0.5455 - val_loss: 1.1679
# Epoch 33/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5387 - loss: 1.1860 - val_accuracy: 0.5200 - val_loss: 1.1713
# Epoch 34/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5206 - loss: 1.1838 - val_accuracy: 0.5164 - val_loss: 1.1599
# Epoch 35/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5407 - loss: 1.1754 - val_accuracy: 0.5527 - val_loss: 1.1421
# Epoch 36/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5153 - loss: 1.1767 - val_accuracy: 0.5418 - val_loss: 1.1588
# Epoch 37/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5332 - loss: 1.1634 - val_accuracy: 0.5455 - val_loss: 1.1442
# Epoch 38/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5238 - loss: 1.1699 - val_accuracy: 0.5782 - val_loss: 1.1255
# Epoch 39/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5682 - loss: 1.1221 - val_accuracy: 0.5600 - val_loss: 1.1078
# Epoch 40/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5368 - loss: 1.1323 - val_accuracy: 0.5818 - val_loss: 1.0940
# Epoch 41/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5632 - loss: 1.0893 - val_accuracy: 0.5673 - val_loss: 1.1156
# Epoch 42/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5555 - loss: 1.1205 - val_accuracy: 0.5491 - val_loss: 1.0829
# Epoch 43/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5497 - loss: 1.1060 - val_accuracy: 0.5891 - val_loss: 1.0747
# Epoch 44/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5585 - loss: 1.0916 - val_accuracy: 0.6000 - val_loss: 1.0559
# Epoch 45/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5766 - loss: 1.0764 - val_accuracy: 0.5818 - val_loss: 1.0653
# Epoch 46/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5778 - loss: 1.0631 - val_accuracy: 0.5964 - val_loss: 1.0427
# Epoch 47/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5727 - loss: 1.0670 - val_accuracy: 0.5927 - val_loss: 1.0751
# Epoch 48/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5670 - loss: 1.0722 - val_accuracy: 0.5891 - val_loss: 1.0538
# Epoch 49/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5808 - loss: 1.0684 - val_accuracy: 0.6073 - val_loss: 1.0231
# Epoch 50/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5889 - loss: 1.0090 - val_accuracy: 0.6145 - val_loss: 1.0120
# Epoch 51/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5826 - loss: 1.0619 - val_accuracy: 0.5964 - val_loss: 1.0506
# Epoch 52/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6091 - loss: 0.9996 - val_accuracy: 0.5964 - val_loss: 1.0195
# Epoch 53/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6096 - loss: 1.0199 - val_accuracy: 0.6145 - val_loss: 1.0181
# Epoch 54/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6143 - loss: 0.9757 - val_accuracy: 0.6145 - val_loss: 1.0235
# Epoch 55/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6020 - loss: 0.9923 - val_accuracy: 0.6109 - val_loss: 1.0227
# Epoch 56/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6135 - loss: 0.9890 - val_accuracy: 0.6364 - val_loss: 1.0076
# Epoch 57/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6313 - loss: 0.9662 - val_accuracy: 0.6400 - val_loss: 0.9876
# Epoch 58/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6154 - loss: 0.9724 - val_accuracy: 0.6473 - val_loss: 0.9597
# Epoch 59/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6023 - loss: 0.9785 - val_accuracy: 0.6436 - val_loss: 0.9853
# Epoch 60/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6193 - loss: 0.9616 - val_accuracy: 0.6400 - val_loss: 0.9892
# Epoch 61/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6391 - loss: 0.9352 - val_accuracy: 0.6545 - val_loss: 0.9646
# Epoch 62/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6312 - loss: 0.9372 - val_accuracy: 0.6582 - val_loss: 0.9583
# Epoch 63/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6197 - loss: 0.9479 - val_accuracy: 0.6509 - val_loss: 0.9814
# Epoch 64/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6235 - loss: 0.9308 - val_accuracy: 0.6400 - val_loss: 0.9640
# Epoch 65/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6444 - loss: 0.9191 - val_accuracy: 0.6655 - val_loss: 0.9427
# Epoch 66/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6135 - loss: 0.9268 - val_accuracy: 0.6473 - val_loss: 0.9690
# Epoch 67/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6487 - loss: 0.9017 - val_accuracy: 0.6473 - val_loss: 0.9434
# Epoch 68/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6523 - loss: 0.8837 - val_accuracy: 0.6364 - val_loss: 0.9517
# Epoch 69/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6600 - loss: 0.8722 - val_accuracy: 0.6764 - val_loss: 0.9190
# Epoch 70/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6453 - loss: 0.9292 - val_accuracy: 0.6764 - val_loss: 0.8999
# Epoch 71/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6420 - loss: 0.9145 - val_accuracy: 0.6691 - val_loss: 0.9313
# Epoch 72/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6397 - loss: 0.9047 - val_accuracy: 0.6727 - val_loss: 0.9448
# Epoch 73/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6719 - loss: 0.8778 - val_accuracy: 0.6582 - val_loss: 0.9173
# Epoch 74/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6549 - loss: 0.8703 - val_accuracy: 0.6764 - val_loss: 0.9229
# Epoch 75/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6706 - loss: 0.8653 - val_accuracy: 0.6691 - val_loss: 0.9370
# Epoch 76/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6748 - loss: 0.8430 - val_accuracy: 0.6727 - val_loss: 0.8898
# Epoch 77/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6500 - loss: 0.8807 - val_accuracy: 0.6764 - val_loss: 0.8853
# Epoch 78/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6680 - loss: 0.8771 - val_accuracy: 0.6764 - val_loss: 0.9185
# Epoch 79/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6773 - loss: 0.8470 - val_accuracy: 0.6727 - val_loss: 0.8957
# Epoch 80/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6718 - loss: 0.8477 - val_accuracy: 0.6582 - val_loss: 0.8849
# Epoch 81/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6984 - loss: 0.8100 - val_accuracy: 0.6909 - val_loss: 0.8702
# Epoch 82/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6634 - loss: 0.8508 - val_accuracy: 0.6764 - val_loss: 0.8738
# Epoch 83/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6752 - loss: 0.8424 - val_accuracy: 0.6545 - val_loss: 0.9260
# Epoch 84/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6632 - loss: 0.8304 - val_accuracy: 0.6727 - val_loss: 0.9016
# Epoch 85/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6771 - loss: 0.8363 - val_accuracy: 0.6764 - val_loss: 0.9068
# Epoch 86/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6810 - loss: 0.8184 - val_accuracy: 0.6655 - val_loss: 0.8723
# Epoch 87/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6666 - loss: 0.8323 - val_accuracy: 0.6691 - val_loss: 0.8989
# Epoch 88/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6879 - loss: 0.8045 - val_accuracy: 0.6982 - val_loss: 0.8410
# Epoch 89/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6962 - loss: 0.7726 - val_accuracy: 0.6727 - val_loss: 0.8827
# Epoch 90/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7054 - loss: 0.7906 - val_accuracy: 0.6691 - val_loss: 0.8603
# Epoch 91/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6856 - loss: 0.7999 - val_accuracy: 0.6836 - val_loss: 0.8903
# Epoch 92/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6834 - loss: 0.7928 - val_accuracy: 0.6836 - val_loss: 0.8512
# Epoch 93/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6930 - loss: 0.7907 - val_accuracy: 0.6909 - val_loss: 0.8731
# Epoch 94/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6913 - loss: 0.7982 - val_accuracy: 0.6691 - val_loss: 0.8364
# Epoch 95/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7076 - loss: 0.7800 - val_accuracy: 0.6836 - val_loss: 0.8486
# Epoch 96/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6738 - loss: 0.8096 - val_accuracy: 0.6727 - val_loss: 0.8989
# Epoch 97/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7236 - loss: 0.7499 - val_accuracy: 0.7018 - val_loss: 0.8494
# Epoch 98/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6931 - loss: 0.7763 - val_accuracy: 0.7018 - val_loss: 0.8602
# Epoch 99/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6853 - loss: 0.7874 - val_accuracy: 0.7127 - val_loss: 0.8441
# Epoch 100/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7105 - loss: 0.7310 - val_accuracy: 0.7055 - val_loss: 0.8683
# Epoch 101/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7071 - loss: 0.7482 - val_accuracy: 0.6982 - val_loss: 0.8463
# Epoch 102/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7301 - loss: 0.7290 - val_accuracy: 0.6945 - val_loss: 0.8643
# Epoch 103/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7159 - loss: 0.7377 - val_accuracy: 0.6982 - val_loss: 0.8448
# Epoch 104/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6999 - loss: 0.7783 - val_accuracy: 0.7127 - val_loss: 0.8205
# Epoch 105/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6945 - loss: 0.7674 - val_accuracy: 0.7091 - val_loss: 0.8521
# Epoch 106/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6920 - loss: 0.7859 - val_accuracy: 0.6873 - val_loss: 0.8264
# Epoch 107/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7064 - loss: 0.7589 - val_accuracy: 0.7091 - val_loss: 0.8282
# Epoch 108/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7362 - loss: 0.7036 - val_accuracy: 0.6982 - val_loss: 0.8410
# Epoch 109/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7182 - loss: 0.7368 - val_accuracy: 0.7345 - val_loss: 0.8022
# Epoch 110/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7170 - loss: 0.7212 - val_accuracy: 0.6982 - val_loss: 0.8209
# Epoch 111/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7084 - loss: 0.7384 - val_accuracy: 0.6945 - val_loss: 0.8394
# Epoch 112/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7146 - loss: 0.7163 - val_accuracy: 0.7236 - val_loss: 0.8140
# Epoch 113/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7106 - loss: 0.7300 - val_accuracy: 0.7091 - val_loss: 0.8134
# Epoch 114/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7385 - loss: 0.7111 - val_accuracy: 0.6982 - val_loss: 0.8329
# Epoch 115/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6978 - loss: 0.7552 - val_accuracy: 0.7309 - val_loss: 0.7949
# Epoch 116/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7110 - loss: 0.7386 - val_accuracy: 0.7309 - val_loss: 0.7980
# Epoch 117/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7298 - loss: 0.6982 - val_accuracy: 0.7309 - val_loss: 0.8127
# Epoch 118/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7232 - loss: 0.7297 - val_accuracy: 0.7018 - val_loss: 0.8342
# Epoch 119/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7254 - loss: 0.7013 - val_accuracy: 0.7309 - val_loss: 0.7980
# Epoch 120/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7392 - loss: 0.6884 - val_accuracy: 0.7236 - val_loss: 0.8154
# Epoch 121/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7373 - loss: 0.6800 - val_accuracy: 0.7055 - val_loss: 0.8223
# Epoch 122/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7340 - loss: 0.6865 - val_accuracy: 0.7236 - val_loss: 0.7587
# Epoch 123/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7313 - loss: 0.7181 - val_accuracy: 0.7164 - val_loss: 0.7844
# Epoch 124/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7270 - loss: 0.6910 - val_accuracy: 0.7164 - val_loss: 0.8036
# Epoch 125/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7294 - loss: 0.6965 - val_accuracy: 0.7236 - val_loss: 0.7996
# Epoch 126/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7318 - loss: 0.6658 - val_accuracy: 0.7018 - val_loss: 0.8358
# Epoch 127/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7453 - loss: 0.6891 - val_accuracy: 0.7236 - val_loss: 0.7912
# Epoch 128/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7566 - loss: 0.6621 - val_accuracy: 0.7200 - val_loss: 0.8010
# Epoch 129/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7331 - loss: 0.6786 - val_accuracy: 0.7345 - val_loss: 0.7812
# Epoch 130/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7532 - loss: 0.6633 - val_accuracy: 0.7345 - val_loss: 0.7925
# Epoch 131/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7534 - loss: 0.6620 - val_accuracy: 0.7418 - val_loss: 0.7812
# Epoch 132/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7577 - loss: 0.6465 - val_accuracy: 0.7200 - val_loss: 0.7672
# Epoch 133/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7619 - loss: 0.6579 - val_accuracy: 0.7200 - val_loss: 0.7956
# Epoch 134/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7393 - loss: 0.6702 - val_accuracy: 0.7382 - val_loss: 0.7555
# Epoch 135/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7384 - loss: 0.6781 - val_accuracy: 0.7200 - val_loss: 0.8085
# Epoch 136/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7363 - loss: 0.6733 - val_accuracy: 0.7345 - val_loss: 0.7851
# Epoch 137/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7499 - loss: 0.6492 - val_accuracy: 0.7273 - val_loss: 0.8007
# Epoch 138/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7259 - loss: 0.7074 - val_accuracy: 0.7345 - val_loss: 0.7710
# Epoch 139/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7556 - loss: 0.6669 - val_accuracy: 0.7273 - val_loss: 0.7616
# Epoch 140/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7464 - loss: 0.6476 - val_accuracy: 0.7200 - val_loss: 0.7969
# Epoch 141/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7612 - loss: 0.6317 - val_accuracy: 0.7418 - val_loss: 0.7619
# Epoch 142/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7558 - loss: 0.6538 - val_accuracy: 0.7418 - val_loss: 0.7766
# Epoch 143/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7624 - loss: 0.6267 - val_accuracy: 0.7127 - val_loss: 0.7637
# Epoch 144/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7656 - loss: 0.6248 - val_accuracy: 0.7418 - val_loss: 0.7744
# Epoch 145/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7648 - loss: 0.6410 - val_accuracy: 0.7273 - val_loss: 0.7400
# Epoch 146/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7656 - loss: 0.6414 - val_accuracy: 0.7236 - val_loss: 0.7837
# Epoch 147/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7581 - loss: 0.6378 - val_accuracy: 0.7345 - val_loss: 0.7700
# Epoch 148/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7608 - loss: 0.6504 - val_accuracy: 0.7236 - val_loss: 0.7824
# Epoch 149/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7609 - loss: 0.6212 - val_accuracy: 0.7345 - val_loss: 0.7435
# Epoch 150/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7797 - loss: 0.6075 - val_accuracy: 0.7418 - val_loss: 0.7392
# Epoch 151/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7619 - loss: 0.6114 - val_accuracy: 0.7418 - val_loss: 0.7720
# Epoch 152/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7758 - loss: 0.6147 - val_accuracy: 0.7491 - val_loss: 0.7540
# Epoch 153/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7741 - loss: 0.6120 - val_accuracy: 0.7382 - val_loss: 0.7348
# Epoch 154/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7581 - loss: 0.6436 - val_accuracy: 0.7345 - val_loss: 0.7591
# Epoch 155/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7742 - loss: 0.5994 - val_accuracy: 0.7309 - val_loss: 0.7961
# Epoch 156/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7691 - loss: 0.6060 - val_accuracy: 0.7345 - val_loss: 0.7206
# Epoch 157/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7656 - loss: 0.5998 - val_accuracy: 0.7309 - val_loss: 0.7572
# Epoch 158/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7640 - loss: 0.5997 - val_accuracy: 0.7309 - val_loss: 0.7738
# Epoch 159/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7603 - loss: 0.6290 - val_accuracy: 0.7418 - val_loss: 0.7794
# Epoch 160/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7782 - loss: 0.6030 - val_accuracy: 0.7345 - val_loss: 0.7496
# Epoch 161/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7582 - loss: 0.6328 - val_accuracy: 0.7527 - val_loss: 0.7730
# Epoch 162/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7741 - loss: 0.5972 - val_accuracy: 0.7491 - val_loss: 0.6994
# Epoch 163/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7547 - loss: 0.6393 - val_accuracy: 0.7455 - val_loss: 0.7506
# Epoch 164/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7899 - loss: 0.5723 - val_accuracy: 0.7382 - val_loss: 0.7417
# Epoch 165/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7697 - loss: 0.6027 - val_accuracy: 0.7345 - val_loss: 0.7373
# Epoch 166/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7642 - loss: 0.6172 - val_accuracy: 0.7309 - val_loss: 0.7750
# Epoch 167/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7768 - loss: 0.6057 - val_accuracy: 0.7418 - val_loss: 0.7391
# Epoch 168/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7686 - loss: 0.5890 - val_accuracy: 0.7418 - val_loss: 0.7494
# Epoch 169/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7703 - loss: 0.5925 - val_accuracy: 0.7527 - val_loss: 0.7411
# Epoch 170/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7684 - loss: 0.6167 - val_accuracy: 0.7527 - val_loss: 0.7565
# Epoch 171/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7935 - loss: 0.5747 - val_accuracy: 0.7673 - val_loss: 0.7210
# Epoch 172/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7889 - loss: 0.5596 - val_accuracy: 0.7309 - val_loss: 0.7673
# Epoch 173/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7918 - loss: 0.5716 - val_accuracy: 0.7527 - val_loss: 0.7559
# Epoch 174/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7858 - loss: 0.5640 - val_accuracy: 0.7491 - val_loss: 0.7704
# Epoch 175/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7896 - loss: 0.5707 - val_accuracy: 0.7636 - val_loss: 0.7349
# Epoch 176/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7741 - loss: 0.5938 - val_accuracy: 0.7564 - val_loss: 0.7452
# Epoch 177/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7711 - loss: 0.5745 - val_accuracy: 0.7745 - val_loss: 0.7134
# Epoch 178/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7829 - loss: 0.5824 - val_accuracy: 0.7491 - val_loss: 0.7650
# Epoch 179/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7748 - loss: 0.5657 - val_accuracy: 0.7527 - val_loss: 0.7139
# Epoch 180/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7838 - loss: 0.5773 - val_accuracy: 0.7636 - val_loss: 0.7174
# Epoch 181/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7866 - loss: 0.5509 - val_accuracy: 0.7345 - val_loss: 0.7600
# Epoch 182/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7896 - loss: 0.5706 - val_accuracy: 0.7455 - val_loss: 0.7181
# Epoch 183/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7832 - loss: 0.5887 - val_accuracy: 0.7564 - val_loss: 0.7091
# Epoch 184/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7715 - loss: 0.6093 - val_accuracy: 0.7564 - val_loss: 0.7038
# Epoch 185/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7899 - loss: 0.5594 - val_accuracy: 0.7455 - val_loss: 0.7199
# Epoch 186/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7918 - loss: 0.5507 - val_accuracy: 0.7673 - val_loss: 0.7032
# Epoch 187/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7854 - loss: 0.5514 - val_accuracy: 0.7564 - val_loss: 0.7178
# Epoch 188/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7905 - loss: 0.5660 - val_accuracy: 0.7673 - val_loss: 0.7088
# Epoch 189/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7791 - loss: 0.5575 - val_accuracy: 0.7564 - val_loss: 0.6860
# Epoch 190/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7967 - loss: 0.5373 - val_accuracy: 0.7382 - val_loss: 0.7283
# Epoch 191/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7977 - loss: 0.5475 - val_accuracy: 0.7564 - val_loss: 0.7125
# Epoch 192/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7845 - loss: 0.5740 - val_accuracy: 0.7673 - val_loss: 0.7089
# Epoch 193/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8041 - loss: 0.5472 - val_accuracy: 0.7564 - val_loss: 0.7168
# Epoch 194/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7925 - loss: 0.5461 - val_accuracy: 0.7745 - val_loss: 0.7085
# Epoch 195/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7924 - loss: 0.5555 - val_accuracy: 0.7600 - val_loss: 0.7037
# Epoch 196/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7979 - loss: 0.5395 - val_accuracy: 0.7673 - val_loss: 0.7044
# Epoch 197/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7989 - loss: 0.5485 - val_accuracy: 0.7491 - val_loss: 0.7334
# Epoch 198/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7941 - loss: 0.5457 - val_accuracy: 0.7491 - val_loss: 0.7185
# Epoch 199/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7767 - loss: 0.5746 - val_accuracy: 0.7491 - val_loss: 0.7186
# Epoch 200/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7911 - loss: 0.5410 - val_accuracy: 0.7673 - val_loss: 0.7342
# Epoch 201/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7924 - loss: 0.5381 - val_accuracy: 0.7636 - val_loss: 0.7052
# Epoch 202/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7902 - loss: 0.5418 - val_accuracy: 0.7636 - val_loss: 0.6969
# Epoch 203/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8049 - loss: 0.5519 - val_accuracy: 0.7600 - val_loss: 0.7270
# Epoch 204/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8065 - loss: 0.5454 - val_accuracy: 0.7782 - val_loss: 0.6798
# Epoch 205/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8057 - loss: 0.5231 - val_accuracy: 0.7636 - val_loss: 0.7175
# Epoch 206/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7791 - loss: 0.5608 - val_accuracy: 0.7600 - val_loss: 0.7044
# Epoch 207/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7899 - loss: 0.5335 - val_accuracy: 0.7673 - val_loss: 0.7141
# Epoch 208/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8068 - loss: 0.4976 - val_accuracy: 0.7564 - val_loss: 0.7107
# Epoch 209/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7910 - loss: 0.5303 - val_accuracy: 0.7564 - val_loss: 0.7148
# Epoch 210/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8081 - loss: 0.5200 - val_accuracy: 0.7709 - val_loss: 0.7047
# Epoch 211/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8047 - loss: 0.5078 - val_accuracy: 0.7673 - val_loss: 0.7096
# Epoch 212/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8142 - loss: 0.5098 - val_accuracy: 0.7927 - val_loss: 0.6850
# Epoch 213/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8099 - loss: 0.5079 - val_accuracy: 0.7673 - val_loss: 0.6933
# Epoch 214/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8072 - loss: 0.5180 - val_accuracy: 0.7636 - val_loss: 0.7011
# Epoch 215/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8008 - loss: 0.5051 - val_accuracy: 0.7673 - val_loss: 0.6870
# Epoch 216/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8018 - loss: 0.5461 - val_accuracy: 0.7673 - val_loss: 0.7070
# Epoch 217/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7906 - loss: 0.5405 - val_accuracy: 0.7673 - val_loss: 0.6963
# Epoch 218/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8045 - loss: 0.5079 - val_accuracy: 0.7818 - val_loss: 0.6987
# Epoch 219/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8138 - loss: 0.5234 - val_accuracy: 0.7818 - val_loss: 0.6702
# Epoch 220/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8098 - loss: 0.5098 - val_accuracy: 0.7600 - val_loss: 0.6939
# Epoch 221/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8061 - loss: 0.5148 - val_accuracy: 0.7855 - val_loss: 0.6709
# Epoch 222/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8162 - loss: 0.5045 - val_accuracy: 0.7527 - val_loss: 0.7371
# Epoch 223/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8009 - loss: 0.5262 - val_accuracy: 0.7745 - val_loss: 0.6998
# Epoch 224/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8042 - loss: 0.5037 - val_accuracy: 0.7745 - val_loss: 0.6978
# Epoch 225/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8236 - loss: 0.4959 - val_accuracy: 0.7818 - val_loss: 0.6836
# Epoch 226/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8117 - loss: 0.5230 - val_accuracy: 0.8036 - val_loss: 0.6804
# Epoch 227/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8022 - loss: 0.5002 - val_accuracy: 0.7818 - val_loss: 0.6875
# Epoch 228/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8220 - loss: 0.5017 - val_accuracy: 0.7855 - val_loss: 0.7074
# Epoch 229/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8275 - loss: 0.4952 - val_accuracy: 0.7855 - val_loss: 0.6869
# Epoch 230/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8061 - loss: 0.5031 - val_accuracy: 0.7891 - val_loss: 0.6923
# Epoch 231/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8136 - loss: 0.4925 - val_accuracy: 0.8000 - val_loss: 0.6754
# Epoch 232/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7891 - loss: 0.5493 - val_accuracy: 0.7745 - val_loss: 0.6741
# Epoch 233/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8167 - loss: 0.5055 - val_accuracy: 0.7855 - val_loss: 0.6747
# Epoch 234/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8196 - loss: 0.4859 - val_accuracy: 0.7855 - val_loss: 0.6891
# Epoch 235/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8393 - loss: 0.4575 - val_accuracy: 0.7745 - val_loss: 0.6819
# Epoch 236/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8188 - loss: 0.4894 - val_accuracy: 0.8073 - val_loss: 0.6510
# Epoch 237/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8284 - loss: 0.4760 - val_accuracy: 0.7927 - val_loss: 0.6716
# Epoch 238/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7937 - loss: 0.5045 - val_accuracy: 0.7891 - val_loss: 0.7050
# Epoch 239/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8223 - loss: 0.4836 - val_accuracy: 0.7818 - val_loss: 0.7040
# Epoch 240/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8190 - loss: 0.4785 - val_accuracy: 0.7636 - val_loss: 0.6786
# Epoch 241/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8385 - loss: 0.4619 - val_accuracy: 0.7636 - val_loss: 0.6985
# Epoch 242/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8329 - loss: 0.4585 - val_accuracy: 0.7636 - val_loss: 0.6851
# Epoch 243/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8146 - loss: 0.4859 - val_accuracy: 0.7709 - val_loss: 0.6833
# Epoch 244/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8183 - loss: 0.4717 - val_accuracy: 0.7818 - val_loss: 0.6926
# Epoch 245/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8265 - loss: 0.4606 - val_accuracy: 0.7818 - val_loss: 0.6917
# Epoch 246/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8344 - loss: 0.4591 - val_accuracy: 0.8000 - val_loss: 0.6523
# Epoch 247/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8264 - loss: 0.4537 - val_accuracy: 0.7818 - val_loss: 0.6955
# Epoch 248/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8363 - loss: 0.4587 - val_accuracy: 0.7855 - val_loss: 0.6935
# Epoch 249/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8290 - loss: 0.4811 - val_accuracy: 0.7782 - val_loss: 0.6828
# Epoch 250/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8251 - loss: 0.4884 - val_accuracy: 0.7964 - val_loss: 0.6389
# Epoch 251/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8354 - loss: 0.4608 - val_accuracy: 0.7964 - val_loss: 0.6677
# Epoch 252/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8294 - loss: 0.4604 - val_accuracy: 0.7564 - val_loss: 0.6906
# Epoch 253/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8280 - loss: 0.4707 - val_accuracy: 0.7709 - val_loss: 0.6897
# Epoch 254/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8181 - loss: 0.4705 - val_accuracy: 0.7964 - val_loss: 0.6668
# Epoch 255/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8374 - loss: 0.4615 - val_accuracy: 0.7745 - val_loss: 0.7020
# Epoch 256/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8331 - loss: 0.4499 - val_accuracy: 0.7891 - val_loss: 0.6573
# Epoch 257/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8269 - loss: 0.4783 - val_accuracy: 0.7891 - val_loss: 0.6540
# Epoch 258/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8199 - loss: 0.4886 - val_accuracy: 0.7709 - val_loss: 0.6965
# Epoch 259/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8196 - loss: 0.4821 - val_accuracy: 0.7818 - val_loss: 0.7033
# Epoch 260/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8173 - loss: 0.4782 - val_accuracy: 0.7709 - val_loss: 0.7366
# Epoch 261/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8314 - loss: 0.4488 - val_accuracy: 0.7891 - val_loss: 0.6849
# Epoch 262/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8214 - loss: 0.4743 - val_accuracy: 0.7709 - val_loss: 0.7199
# Epoch 263/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8174 - loss: 0.4907 - val_accuracy: 0.7673 - val_loss: 0.7162
# Epoch 264/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8244 - loss: 0.4720 - val_accuracy: 0.7818 - val_loss: 0.7524
# Epoch 265/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8331 - loss: 0.4648 - val_accuracy: 0.7891 - val_loss: 0.6806
# Epoch 266/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8306 - loss: 0.4585 - val_accuracy: 0.8000 - val_loss: 0.6657
# Epoch 267/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8281 - loss: 0.4567 - val_accuracy: 0.7709 - val_loss: 0.7087
# Epoch 268/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8293 - loss: 0.4685 - val_accuracy: 0.7818 - val_loss: 0.6689
# Epoch 269/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8259 - loss: 0.4436 - val_accuracy: 0.7927 - val_loss: 0.6838
# Epoch 270/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8368 - loss: 0.4639 - val_accuracy: 0.7782 - val_loss: 0.6899
# Epoch 271/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8285 - loss: 0.4874 - val_accuracy: 0.7818 - val_loss: 0.6849
# Epoch 272/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8131 - loss: 0.4807 - val_accuracy: 0.7855 - val_loss: 0.6783
# Epoch 273/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8430 - loss: 0.4372 - val_accuracy: 0.8145 - val_loss: 0.6573
# Epoch 274/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8244 - loss: 0.4572 - val_accuracy: 0.8000 - val_loss: 0.6607
# Epoch 275/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8353 - loss: 0.4607 - val_accuracy: 0.8036 - val_loss: 0.6496
# Epoch 276/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8391 - loss: 0.4152 - val_accuracy: 0.7855 - val_loss: 0.6857
# Epoch 277/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8349 - loss: 0.4372 - val_accuracy: 0.7964 - val_loss: 0.6819
# Epoch 278/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8263 - loss: 0.4543 - val_accuracy: 0.7782 - val_loss: 0.6840
# Epoch 279/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8439 - loss: 0.4291 - val_accuracy: 0.8000 - val_loss: 0.6555
# Epoch 280/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8187 - loss: 0.4755 - val_accuracy: 0.7927 - val_loss: 0.6687
# Epoch 281/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8529 - loss: 0.4197 - val_accuracy: 0.8109 - val_loss: 0.6954
# Epoch 282/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8471 - loss: 0.4243 - val_accuracy: 0.8109 - val_loss: 0.6599
# Epoch 283/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8374 - loss: 0.4325 - val_accuracy: 0.8036 - val_loss: 0.6629
# Epoch 284/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8375 - loss: 0.4345 - val_accuracy: 0.8036 - val_loss: 0.6893
# Epoch 285/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8376 - loss: 0.4102 - val_accuracy: 0.7855 - val_loss: 0.6943
# Epoch 286/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8299 - loss: 0.4639 - val_accuracy: 0.7782 - val_loss: 0.6886
# Epoch 287/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8355 - loss: 0.4445 - val_accuracy: 0.8218 - val_loss: 0.6486
# Epoch 288/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8198 - loss: 0.4972 - val_accuracy: 0.8073 - val_loss: 0.6668
# Epoch 289/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8307 - loss: 0.4547 - val_accuracy: 0.8000 - val_loss: 0.6901
# Epoch 290/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8414 - loss: 0.4524 - val_accuracy: 0.8036 - val_loss: 0.6959
# Epoch 291/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8456 - loss: 0.4119 - val_accuracy: 0.7891 - val_loss: 0.6851
# Epoch 292/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8534 - loss: 0.3874 - val_accuracy: 0.8000 - val_loss: 0.6757
# Epoch 293/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8335 - loss: 0.4368 - val_accuracy: 0.7855 - val_loss: 0.6736
# Epoch 294/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8432 - loss: 0.4250 - val_accuracy: 0.8218 - val_loss: 0.6581
# Epoch 295/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8479 - loss: 0.4280 - val_accuracy: 0.8109 - val_loss: 0.6708
# Epoch 296/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8504 - loss: 0.4073 - val_accuracy: 0.8145 - val_loss: 0.6692
# Epoch 297/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8447 - loss: 0.4299 - val_accuracy: 0.8000 - val_loss: 0.6778
# Epoch 298/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8289 - loss: 0.4493 - val_accuracy: 0.8218 - val_loss: 0.6614
# Epoch 299/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8456 - loss: 0.4273 - val_accuracy: 0.8073 - val_loss: 0.6418
# Epoch 300/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8446 - loss: 0.4193 - val_accuracy: 0.7855 - val_loss: 0.6622
# Epoch 301/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8598 - loss: 0.3974 - val_accuracy: 0.8182 - val_loss: 0.6751
# Epoch 302/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8541 - loss: 0.4139 - val_accuracy: 0.7891 - val_loss: 0.6705
# Epoch 303/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8454 - loss: 0.4232 - val_accuracy: 0.8036 - val_loss: 0.6704
# Epoch 304/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8538 - loss: 0.3991 - val_accuracy: 0.8073 - val_loss: 0.6664
# Epoch 305/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8548 - loss: 0.4092 - val_accuracy: 0.8073 - val_loss: 0.6654
# Epoch 306/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8494 - loss: 0.4074 - val_accuracy: 0.8073 - val_loss: 0.6377
# Epoch 307/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8283 - loss: 0.4393 - val_accuracy: 0.8145 - val_loss: 0.6437
# Epoch 308/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8370 - loss: 0.4293 - val_accuracy: 0.8036 - val_loss: 0.6725
# Epoch 309/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8499 - loss: 0.4066 - val_accuracy: 0.7891 - val_loss: 0.6994
# Epoch 310/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8458 - loss: 0.4174 - val_accuracy: 0.8109 - val_loss: 0.6703
# Epoch 311/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8390 - loss: 0.4184 - val_accuracy: 0.7927 - val_loss: 0.6647
# Epoch 312/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8384 - loss: 0.4346 - val_accuracy: 0.8036 - val_loss: 0.6659
# Epoch 313/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8486 - loss: 0.4077 - val_accuracy: 0.8036 - val_loss: 0.7251
# Epoch 314/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8392 - loss: 0.4365 - val_accuracy: 0.8036 - val_loss: 0.6618
# Epoch 315/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8283 - loss: 0.4496 - val_accuracy: 0.8109 - val_loss: 0.6560
# Epoch 316/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8423 - loss: 0.4103 - val_accuracy: 0.8109 - val_loss: 0.6680
# Epoch 317/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8361 - loss: 0.4109 - val_accuracy: 0.7964 - val_loss: 0.6565
# Epoch 318/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8496 - loss: 0.4101 - val_accuracy: 0.8036 - val_loss: 0.6688
# Epoch 319/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8713 - loss: 0.3807 - val_accuracy: 0.8036 - val_loss: 0.6594
# Epoch 320/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8450 - loss: 0.4115 - val_accuracy: 0.8073 - val_loss: 0.6372
# Epoch 321/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8483 - loss: 0.3918 - val_accuracy: 0.8182 - val_loss: 0.6589
# Epoch 322/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8558 - loss: 0.3871 - val_accuracy: 0.8109 - val_loss: 0.6308
# Epoch 323/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8531 - loss: 0.4127 - val_accuracy: 0.8109 - val_loss: 0.6606
# Epoch 324/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8526 - loss: 0.3859 - val_accuracy: 0.8073 - val_loss: 0.6630
# Epoch 325/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8484 - loss: 0.3995 - val_accuracy: 0.8000 - val_loss: 0.6644
# Epoch 326/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8599 - loss: 0.3773 - val_accuracy: 0.8073 - val_loss: 0.6505
# Epoch 327/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8422 - loss: 0.4211 - val_accuracy: 0.8073 - val_loss: 0.6437
# Epoch 328/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8664 - loss: 0.3756 - val_accuracy: 0.8109 - val_loss: 0.6885
# Epoch 329/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8420 - loss: 0.4307 - val_accuracy: 0.7891 - val_loss: 0.6702
# Epoch 330/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8609 - loss: 0.3563 - val_accuracy: 0.8145 - val_loss: 0.6666
# Epoch 331/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8520 - loss: 0.3970 - val_accuracy: 0.8218 - val_loss: 0.6529
# Epoch 332/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8649 - loss: 0.3700 - val_accuracy: 0.8145 - val_loss: 0.6873
# Epoch 333/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8508 - loss: 0.4133 - val_accuracy: 0.8218 - val_loss: 0.6369
# Epoch 334/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8535 - loss: 0.3736 - val_accuracy: 0.8145 - val_loss: 0.6727
# Epoch 335/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8527 - loss: 0.4092 - val_accuracy: 0.8145 - val_loss: 0.6364
# Epoch 336/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8550 - loss: 0.3984 - val_accuracy: 0.8182 - val_loss: 0.6429
# Epoch 337/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8655 - loss: 0.3636 - val_accuracy: 0.8182 - val_loss: 0.6834
# Epoch 338/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8642 - loss: 0.3764 - val_accuracy: 0.8182 - val_loss: 0.6382
# Epoch 339/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8647 - loss: 0.3668 - val_accuracy: 0.8218 - val_loss: 0.6802
# Epoch 340/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8612 - loss: 0.3798 - val_accuracy: 0.8145 - val_loss: 0.6491
# Epoch 341/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8628 - loss: 0.3694 - val_accuracy: 0.8109 - val_loss: 0.6360
# Epoch 342/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8654 - loss: 0.3528 - val_accuracy: 0.8291 - val_loss: 0.6340
# Epoch 343/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8602 - loss: 0.3550 - val_accuracy: 0.8218 - val_loss: 0.6432
# Epoch 344/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8632 - loss: 0.3771 - val_accuracy: 0.8182 - val_loss: 0.6129
# Epoch 345/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8561 - loss: 0.3834 - val_accuracy: 0.8182 - val_loss: 0.6441
# Epoch 346/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8517 - loss: 0.4153 - val_accuracy: 0.8182 - val_loss: 0.6362
# Epoch 347/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8671 - loss: 0.3584 - val_accuracy: 0.8182 - val_loss: 0.6284
# Epoch 348/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8638 - loss: 0.3773 - val_accuracy: 0.8291 - val_loss: 0.6035
# Epoch 349/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8703 - loss: 0.3557 - val_accuracy: 0.8364 - val_loss: 0.6014
# Epoch 350/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8663 - loss: 0.3902 - val_accuracy: 0.8255 - val_loss: 0.6409
# Epoch 351/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8576 - loss: 0.3663 - val_accuracy: 0.8255 - val_loss: 0.5941
# Epoch 352/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8710 - loss: 0.3635 - val_accuracy: 0.8255 - val_loss: 0.6177
# Epoch 353/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8718 - loss: 0.3575 - val_accuracy: 0.8255 - val_loss: 0.6518
# Epoch 354/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8593 - loss: 0.3808 - val_accuracy: 0.8145 - val_loss: 0.6625
# Epoch 355/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8509 - loss: 0.3969 - val_accuracy: 0.8109 - val_loss: 0.6835
# Epoch 356/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8550 - loss: 0.4043 - val_accuracy: 0.8218 - val_loss: 0.6436
# Epoch 357/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8432 - loss: 0.4114 - val_accuracy: 0.8109 - val_loss: 0.6481
# Epoch 358/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8600 - loss: 0.3775 - val_accuracy: 0.8000 - val_loss: 0.7016
# Epoch 359/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8597 - loss: 0.3965 - val_accuracy: 0.8182 - val_loss: 0.6886
# Epoch 360/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8561 - loss: 0.3699 - val_accuracy: 0.8109 - val_loss: 0.6447
# Epoch 361/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8467 - loss: 0.3985 - val_accuracy: 0.8182 - val_loss: 0.6700
# Epoch 362/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8518 - loss: 0.3684 - val_accuracy: 0.8182 - val_loss: 0.6530
# Epoch 363/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8677 - loss: 0.3645 - val_accuracy: 0.7964 - val_loss: 0.7050
# Epoch 364/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8723 - loss: 0.3576 - val_accuracy: 0.7964 - val_loss: 0.6691
# Epoch 365/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8702 - loss: 0.3696 - val_accuracy: 0.8255 - val_loss: 0.6576
# Epoch 366/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8677 - loss: 0.3435 - val_accuracy: 0.8291 - val_loss: 0.6164
# Epoch 367/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8789 - loss: 0.3440 - val_accuracy: 0.8145 - val_loss: 0.6721
# Epoch 368/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8759 - loss: 0.3488 - val_accuracy: 0.8255 - val_loss: 0.6507
# Epoch 369/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8643 - loss: 0.3445 - val_accuracy: 0.8218 - val_loss: 0.6606
# Epoch 370/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8693 - loss: 0.3601 - val_accuracy: 0.8145 - val_loss: 0.6599
# Epoch 371/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8764 - loss: 0.3539 - val_accuracy: 0.8073 - val_loss: 0.6699
# Epoch 372/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8630 - loss: 0.3695 - val_accuracy: 0.8109 - val_loss: 0.6760
# Epoch 373/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8618 - loss: 0.3713 - val_accuracy: 0.8255 - val_loss: 0.6675
# Epoch 374/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8749 - loss: 0.3364 - val_accuracy: 0.8291 - val_loss: 0.6312
# Epoch 375/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8806 - loss: 0.3219 - val_accuracy: 0.8255 - val_loss: 0.6356
# Epoch 376/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8760 - loss: 0.3556 - val_accuracy: 0.8036 - val_loss: 0.6853
# Epoch 377/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8773 - loss: 0.3294 - val_accuracy: 0.8036 - val_loss: 0.6651
# Epoch 378/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8589 - loss: 0.3606 - val_accuracy: 0.8109 - val_loss: 0.6760
# Epoch 379/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8622 - loss: 0.3761 - val_accuracy: 0.8145 - val_loss: 0.6302
# Epoch 380/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8783 - loss: 0.3459 - val_accuracy: 0.8182 - val_loss: 0.6760
# Epoch 381/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8753 - loss: 0.3536 - val_accuracy: 0.8145 - val_loss: 0.6551
# Epoch 382/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8781 - loss: 0.3367 - val_accuracy: 0.8255 - val_loss: 0.6275
# Epoch 383/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8695 - loss: 0.3621 - val_accuracy: 0.8218 - val_loss: 0.6501
# Epoch 384/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8719 - loss: 0.3583 - val_accuracy: 0.8218 - val_loss: 0.6409
# Epoch 385/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8713 - loss: 0.3646 - val_accuracy: 0.8255 - val_loss: 0.6259
# Epoch 386/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8630 - loss: 0.3846 - val_accuracy: 0.8436 - val_loss: 0.6095
# Epoch 387/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8563 - loss: 0.3688 - val_accuracy: 0.8218 - val_loss: 0.6180
# Epoch 388/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8648 - loss: 0.3548 - val_accuracy: 0.8255 - val_loss: 0.6135
# Epoch 389/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8767 - loss: 0.3359 - val_accuracy: 0.8145 - val_loss: 0.6311
# Epoch 390/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8685 - loss: 0.3684 - val_accuracy: 0.8364 - val_loss: 0.5862
# Epoch 391/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8653 - loss: 0.3544 - val_accuracy: 0.8364 - val_loss: 0.6258
# Epoch 392/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8617 - loss: 0.3605 - val_accuracy: 0.8218 - val_loss: 0.6111
# Epoch 393/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8778 - loss: 0.3357 - val_accuracy: 0.8364 - val_loss: 0.6153
# Epoch 394/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8673 - loss: 0.3462 - val_accuracy: 0.8291 - val_loss: 0.6092
# Epoch 395/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8728 - loss: 0.3411 - val_accuracy: 0.8327 - val_loss: 0.6511
# Epoch 396/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8888 - loss: 0.3405 - val_accuracy: 0.8255 - val_loss: 0.6292
# Epoch 397/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8705 - loss: 0.3436 - val_accuracy: 0.8182 - val_loss: 0.6660
# Epoch 398/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8808 - loss: 0.3469 - val_accuracy: 0.8255 - val_loss: 0.6303
# Epoch 399/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8803 - loss: 0.3509 - val_accuracy: 0.8255 - val_loss: 0.6035
# Epoch 400/400
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8845 - loss: 0.3267 - val_accuracy: 0.8400 - val_loss: 0.5852
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8317 - loss: 0.6380
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Confusion Matrix:
#  [[49  5  3  1  1]
#  [ 5 49  0  1  0]
#  [ 1  4 41  0  3]
#  [ 0  6  2 46  2]
#  [ 2  2  1  5 46]]
# Per-class accuracy:
# Label 0 accuracy: 83.1%
# Label 1 accuracy: 89.1%
# Label 2 accuracy: 83.7%
# Label 3 accuracy: 82.1%
# Label 4 accuracy: 82.1%

# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# Create a folder for plots
plot_dir = "plots"
os.makedirs(plot_dir, exist_ok=True)

# === Confusion Matrix Heatmap ===
def plot_confusion_matrix_heatmap(conf_mat):
    plt.figure(figsize=(8, 6))
    labels = [0, 1, 2, 3, 4]
    sns.heatmap(conf_mat, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix Heatmap")
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, "confusion_matrix_heatmap.png"))
    plt.show()

# === Per-Class Accuracy Bar Chart ===
def plot_per_class_accuracy(conf_mat):
    labels = [0, 1, 2, 3, 4]
    per_class_acc = [100 * conf_mat[i, i] / sum(conf_mat[i]) if sum(conf_mat[i]) > 0 else 0 for i in labels]
    
    plt.figure(figsize=(8, 5))
    plt.bar(labels, per_class_acc, color="skyblue")
    plt.ylim(0, 100)
    plt.xlabel("Class Label")
    plt.ylabel("Accuracy (%)")
    plt.title("Per-Class Accuracy")
    plt.grid(axis='y')
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, "per_class_accuracy.png"))
    plt.show()

# === Training vs Validation Accuracy ===
def plot_training_validation_accuracy(history):
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.title("Training vs. Validation Accuracy")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, "training_vs_validation_accuracy.png"))
    plt.show()

# === Training vs Validation Loss ===
def plot_training_validation_loss(history):
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training vs. Validation Loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, "training_vs_validation_loss.png"))
    plt.show()

# === Prediction vs True Class Distribution ===
def plot_prediction_distribution(y_test, y_pred):
    labels = [0, 1, 2, 3, 4]
    plt.figure(figsize=(8, 4))
    plt.hist(y_test, bins=np.arange(6)-0.5, alpha=0.5, label="True", color='g', rwidth=0.9)
    plt.hist(y_pred, bins=np.arange(6)-0.5, alpha=0.5, label="Predicted", color='r', rwidth=0.6)
    plt.xticks(labels)
    plt.xlabel("Class Label")
    plt.ylabel("Count")
    plt.title("True vs. Predicted Class Distribution")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, "true_vs_predicted_distribution.png"))
    plt.show()

# === Run and Save All Plots ===
plot_confusion_matrix_heatmap(conf_mat)
plot_per_class_accuracy(conf_mat)
plot_training_validation_accuracy(history)
plot_training_validation_loss(history)
plot_prediction_distribution(y_test, y_pred)

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Using cached imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Using cached imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn->imblearn)
#   Using cached sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Using cached imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Using cached sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.13.0 imblearn-0.0 sklearn-compat-0.1.3
